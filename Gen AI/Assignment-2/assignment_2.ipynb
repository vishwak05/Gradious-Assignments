# %% [markdown]
# - Refer the attached notebook. It uses HuggigFace meta-llama/Llama-2-7b-chat-hf model to predict if the given news sentiment is positive, negative or neutral.
# - Refer the attached data file in csv format which has labelling for the sentiment classification. The notebook runs test against the base model and prints the evaluation metics.
# - Then fine tunes the model with the training data. For this excerside Google Colab V100 CPU is used. You will get out of memory error with smaller runtimes.
# - Execute this and write summary about this including various parameters used for fine tuning and your observations.

# %% [markdown]
# Google Colab V100 CPU is Deprecated and not available
#
# Using T4 GPU with 15 GB RAM Runtime
#
# Using Smaller LLM for task as **meta-llama/llama-2-7B-chat-hf** utilizes all of the GPU RAM
#
# Model used: **Facebook/bart-large-mnli**

# %%
# Installing packages
# !pip install -q datasets transformers langchain langchain_community accelerate langchain-huggingface

# %%
# Logging into Hugging Face
# !hf auth login
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `hf`CLI if you want to set the git credential as well.
# Token is valid (permission: read).
# The token `sentiment-analysis` has been saved to /teamspace/studios/this_studio/.cache/huggingface/stored_tokens
# Your token has been saved to /teamspace/studios/this_studio/.cache/huggingface/token
# Login successful.
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
import pandas as pd

# %%
# Loading dataset
text_data = pd.read_csv("all-data_fin.csv", names=['sentiment', 'text'])
text_data
# Out:
#      sentiment                                               text
# 0      neutral  According to Gran , the company has no plans t...
# 1      neutral  Technopolis plans to develop in stages an area...
# 2     negative  The international electronic industry company ...
# 3     positive  With the new production plant the company woul...
# 4     positive  According to the company 's updated strategy f...
# ...        ...                                                ...
# 4841  negative  LONDON MarketWatch -- Share prices ended lower...
# 4842   neutral  Rinkuskiai 's beer sales fell by 6.5 per cent ...
# 4843  negative  Operating profit fell to EUR 35.4 mn from EUR ...
# 4844  negative  Net sales of the Paper segment decreased to EU...
# 4845  negative  Sales in Finland decreased by 10.5 % in Januar...
#
# [4846 rows x 2 columns]

# %%
text_data.isna().sum()
# Out:
# sentiment    0
# text         0
# dtype: int64

# %%
text_data.duplicated().sum()
# Out:
# 6

# %%
text_data[text_data.duplicated(keep=False)]
# Out:
#      sentiment                                               text
# 1098   neutral  The issuer is solely responsible for the conte...
# 1099   neutral  The issuer is solely responsible for the conte...
# 1415   neutral  The report profiles 614 companies including ma...
# 1416   neutral  The report profiles 614 companies including ma...
# 2395   neutral  Ahlstrom 's share is quoted on the NASDAQ OMX ...
# 2396   neutral  Ahlstrom 's share is quoted on the NASDAQ OMX ...
# 2566   neutral  SSH Communications Security Corporation is hea...
# 2567   neutral  SSH Communications Security Corporation is hea...
# 3093   neutral  Proha Plc ( Euronext :7327 ) announced today (...
# 3094   neutral  Proha Plc ( Euronext :7327 ) announced today (...
# 3205   neutral  The company serves customers in various indust...
# 3206   neutral  The company serves customers in various indust...

# %%
# Dropping duplicate values
text_data.drop_duplicates(inplace=True)

# %%
text_data['sentiment'].value_counts(dropna=True)
# Out:
# sentiment
# neutral     2873
# positive    1363
# negative     604
# Name: count, dtype: int64

# %%
# Sentiments
categories = ['neutral', 'positive', 'negative']

# %%
from transformers import AutoTokenizer, pipeline

# %%
# Creating pre-trained model instance and tokenizer
model_name = "facebook/bart-large-mnli"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
# Creating pipeline
classifier = pipeline(
    task="zero-shot-classification",
    model=model_name,
    tokenizer=tokenizer,
    device_map="auto"
)
# Out:
# Device set to use cuda:0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(text_data['text'], text_data['sentiment'], test_size=0.2, random_state=42)

# %%
# Predicting sentiments with pre-trained model
y_pred = classifier(X_test.tolist(), candidate_labels=categories)
y_pred
# Out:
# [{'sequence': 'The company serves customers in various industries , including process and resources , industrial machinery , architecture , building , construction , electrical , transportation , electronics , chemical , petrochemical , energy , and information technology , as well as catering and households .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.7203370332717896, 0.14087985455989838, 0.13878309726715088]},
#  {'sequence': 'Officials did not disclose the contract value .',
#   'labels': ['neutral', 'negative', 'positive'],
#   'scores': [0.44559445977211, 0.4096296429634094, 0.1447758823633194]},
#  {'sequence': 'The extracted filtrates are very high in clarity while the dried filter cakes meet required transport moisture limits (TMLs)for their ore grades .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.939456582069397, 0.04339035600423813, 0.017152994871139526]},
#  {'sequence': 'The tool is a patent pending design that allows consumers to lay out their entire project on a removable plate using multiple clear stamps of any kind .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.6960019469261169, 0.21128204464912415, 0.0927160382270813]},
#  {'sequence': "In Finland , the corresponding service is Alma Media 's Etuovi.com , Finland 's most popular and best known nationwide online service for home and property sales .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.5276354551315308, 0.33056312799453735, 0.1418014019727707]},
#  {'sequence': "Sanoma also has an Executive Committee , in accordance with the Company 's Articles of Association , that prepares proposals for matters to be decided or noted by the Board of Directors .",
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.3664281666278839, 0.31890931725502014, 0.31466251611709595]},
#  {'sequence': 'Finnish property investment company Citycon plans to issue directed subordinated convertible bonds to institutional investors .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.45799657702445984, 0.3494255542755127, 0.19257795810699463]},
#  {'sequence': 'The gross area of the Innova 2 project will be about 10,000 sq m ( 107,600 sq ft ) .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.43538060784339905, 0.3461674451828003, 0.21845194697380066]},
#  {'sequence': "Glaston 's own glass processing unit , Tamglass Glass Processing , is a manufacturer of high quality safety glass products , and operates in Finland .",
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.6099374890327454, 0.19902829825878143, 0.191034197807312]},
#  {'sequence': 'Combined net sales in 2006 were $ 27 million and EBITDA was $ 13.7 million .',
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.6405950784683228, 0.2526218891143799, 0.10678304731845856]},
#  {'sequence': 'No service pricing details were disclosed .',
#   'labels': ['neutral', 'negative', 'positive'],
#   'scores': [0.7704223990440369, 0.1732998788356781, 0.05627768859267235]},
#  {'sequence': 'INTERNET BUSINESS NEWS - -_ 1995-2006 M2 COMMUNICATIONS LTD As part of a drive to protect users of its Internet banking service , Barclays Bank has announced that it is to recommend F-Secure Internet Security to its customers .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.69113689661026, 0.21166928112506866, 0.09719385206699371]},
#  {'sequence': 'All depends on financing .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.4426852762699127, 0.32455602288246155, 0.23275870084762573]},
#  {'sequence': "Forestries were also higher , driven by yesterday 's bullish analyst comment on Stora Enso in Dagens Industri , dealers said .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9732402563095093, 0.017962809652090073, 0.008796894922852516]},
#  {'sequence': 'In stead of being based on a soft drink , as is usual , the Teho energy drink is made with fresh water .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.36211520433425903, 0.32624658942222595, 0.3116382360458374]},
#  {'sequence': 'Finnish house manufacturers are targeting the strongly growing one-family house market in Russia .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.8358636498451233, 0.12719844281673431, 0.036937929689884186]},
#  {'sequence': "Local government commissioner of +_m+_l , Kurt Svensson , says he will contact the management of Finnish company Componenta to find out if there are any alternatives to the company 's decision to close down its plant in +_m+_l .",
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.92243891954422, 0.039055828005075455, 0.03850525617599487]},
#  {'sequence': "And that 's exactly what happened on a recent weekday when an East Haven baker was brought in to remind residents about the Easter tradition of making wheat and rice pies .",
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.7108244299888611, 0.17012764513492584, 0.11904788017272949]},
#  {'sequence': 'Following the increase the company+ˆEUR TM s capital totals 5.5 mln Romanian lei $ 1.98 mln-1 .56 mln euro .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.7312766909599304, 0.13564299046993256, 0.13308031857013702]},
#  {'sequence': 'Net sales will , however , increase from 2005 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.750608503818512, 0.20542225241661072, 0.04396926611661911]},
#  {'sequence': 'The insurance division turned a EUR120m profit .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9748086929321289, 0.013871399685740471, 0.01131990272551775]},
#  {'sequence': "At 10.33 am , Huhtamaki was the market 's biggest faller , 8.69 pct lower at 11.35 eur , while the OMX Helsinki 25 was 0.32 pct higher at 3,332.41 , and the OMX Helsinki was up 0.47 pct at 11,687.32 .",
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.758004367351532, 0.12845247983932495, 0.11354314535856247]},
#  {'sequence': 'Operating profit rose to EUR 13.1 mn from EUR 8.7 mn in the corresponding period in 2007 representing 7.7 % of net sales .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.922455906867981, 0.05533960089087486, 0.022204458713531494]},
#  {'sequence': 'The copying , republication or redistribution of AFX News Content , including by framing or similar means , is expressly prohibited without the prior written consent of AFX News .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.5111194849014282, 0.2731017768383026, 0.21577870845794678]},
#  {'sequence': 'The Web-Marela application handles invitations to quote , quote comparisons , agreements , purchases , invoice inspections , inventory management , and deliveries .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.6851739883422852, 0.2090795934200287, 0.10574642568826675]},
#  {'sequence': 'Kesko offers Hilton to open a hotel on Kalinisky prospect in a 18,000-square metres building because of these difficulties .',
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.5437992811203003, 0.24065780639648438, 0.21554288268089294]},
#  {'sequence': 'Finland-based international machinery rental company Ramirent Plc ( OMX Helsinki : RMR1V ) said on Friday ( 9 May ) that its president and CEO , Kari Kallio , has informed the board of his intention to retire in year 2009 .',
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.683702290058136, 0.16766691207885742, 0.1486307829618454]},
#  {'sequence': "The reasons behind the estimate include the rise in 2008 rent levels and several fully-leased office and retail properties , which were completed and added to the company 's investment property portfolio .",
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.6600054502487183, 0.17581477761268616, 0.16417978703975677]},
#  {'sequence': "Image data produced by the browser at the phone server is converted into a bitmapped image that is sent to the handset for display . ''",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.40894946455955505, 0.4036034345626831, 0.18744713068008423]},
#  {'sequence': 'Based on the design of previous handsets , the Nokia E72 and Nokia E63 this Symbian-based model is promised to offer direct access to over 90 per cent of the world s corporate email through Mail for Exchange and IBM Lotus Notes Traveler .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.8382884860038757, 0.11052096635103226, 0.0511905774474144]},
#  {'sequence': 'Rental of building equipment accounted for 88 percent of the operating income .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.49616116285324097, 0.27054327726364136, 0.2332955002784729]},
#  {'sequence': 'Following the registration , the share capital of Biotie is EUR 52,556,678.10 .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.5080418586730957, 0.33808988332748413, 0.15386828780174255]},
#  {'sequence': 'The goal will be achieved via organic growth possibly supplemented by acquisitions .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.6928305625915527, 0.2205919772386551, 0.08657746016979218]},
#  {'sequence': 'Revenue was slightly down , at  x20ac 495 million $ 634 million , compared to  x20ac 497 million a year earlier .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.5950836539268494, 0.3670182228088379, 0.03789814934134483]},
#  {'sequence': 'Thanks to its extensive industry and operations experience , Cybercom offers strategic and technological expertise to these markets : telecom , industry , media , public sector , retail , and banking and financial services .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9341716766357422, 0.04423542320728302, 0.021592898294329643]},
#  {'sequence': 'Ruukki Romania , the local arm of Finnish metal producer Ruukki , increased its capital by 900,000 euro ( $ 1.14 mln ) through cash contribution , it was reported on September 19 , 2006 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.609773576259613, 0.23785242438316345, 0.1523740291595459]},
#  {'sequence': 'At CapMan Haavisto will be responsible for Group Finances and Accounting and IT .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.5176882147789001, 0.276045560836792, 0.20626622438430786]},
#  {'sequence': 'The EBRD is using its own funds to provide a 21.6 mln A loan while the B portion of 10 mln Euros has been syndicated to two Finnish commercial banks , Nordea Bank Finland Plc 7.7 mln Euros and Pohjola Bank Plc 2.3 mln Euros .',
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.563794732093811, 0.31302401423454285, 0.12318117916584015]},
#  {'sequence': 'Panostaja did not disclose the purchase price .',
#   'labels': ['neutral', 'negative', 'positive'],
#   'scores': [0.4148518741130829, 0.34112662076950073, 0.2440214902162552]},
#  {'sequence': 'The Internal Revenue Service sees about 20 percent of all taxpayers wait until the last two weeks to file , with about 40 million returns filed in April .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.3604947328567505, 0.3513643443584442, 0.2881409227848053]},
#  {'sequence': '`` With this agreement , we can continue our good cooperationand at the same time release capital that has been tied up in ourmachinery operation .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9437561631202698, 0.04230071231722832, 0.013943186029791832]},
#  {'sequence': 'GS Engineering will install the valves at a liquefied natural gas LNG plant it has built for UAE LNG extraction and gas plants operator GASCO in Ruwais , UAE .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.6420167684555054, 0.22029200196266174, 0.13769122958183289]},
#  {'sequence': '`` The lowering of prices by us and by our competitors shows that the real estate market has stabilised and returned into balance and apartments are acquiring a fair price in the eyes of our clients .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.926278829574585, 0.055355172604322433, 0.018366042524576187]},
#  {'sequence': 'The companies expect the first orders already in 2011 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.681239664554596, 0.20643867552280426, 0.112321637570858]},
#  {'sequence': 'Net income from life insurance doubled to EUR 6.8 mn from EUR 3.2 mn , and net income from non-life insurance rose to EUR 5.2 mn from EUR 1.5 mn in the corresponding period in 2009 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.964006245136261, 0.021973980590701103, 0.014019775204360485]},
#  {'sequence': 'ALEXANDRIA , Va. , Oct. 6 -- United States Patent no. 7,804,288 , issued on Sept. 28 , was assigned to Vacon Oyj ( Vaasa , Finland ) .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.42629149556159973, 0.32342150807380676, 0.2502870261669159]},
#  {'sequence': '128,538 shares can still be subscribed for with Series E share options , max .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.5083183646202087, 0.2834089398384094, 0.20827263593673706]},
#  {'sequence': 'However , he expects banks to provide alternative financing .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.456535667181015, 0.36117464303970337, 0.1822897046804428]},
#  {'sequence': 'The chain posted sales of 298 million euros for full 2005 , a rise of 19.5 percent , year-on-year .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9073836207389832, 0.07123713195323944, 0.02137923054397106]},
#  {'sequence': "The company 's advantage in pricing can be seen in the significantly lower prices offered by the new unmanned stations .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.90022212266922, 0.05155165120959282, 0.048226241022348404]},
#  {'sequence': 'The company said production volumes so far indicate the circuit is capable of the targeted output rate of 60,000 tonnes per day , or 22 million tonnes a year .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.875263512134552, 0.09213390946388245, 0.03260260447859764]},
#  {'sequence': 'The ore body is sufficient to support anticipated production for at least 46 years .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9073883891105652, 0.06215031072497368, 0.030461374670267105]},
#  {'sequence': "`` UPM 's deliveries increased during the third quarter by 4 percent , and the efficiency of operations improved , '' Chief Executive Jussi Pesonen said .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.8926246762275696, 0.07430034130811691, 0.033074941486120224]},
#  {'sequence': 'Finnish developer and manufacturer of mobile phone chargers Salcomp Plc OMX Helsinki : SAL1V on Wednesday 19 November lowered its full-year net sales estimate .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.894614040851593, 0.07401971518993378, 0.03136624023318291]},
#  {'sequence': "- Counter your competitor 's strengths and target their weaknesses .",
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.4970324635505676, 0.34659871459007263, 0.15636879205703735]},
#  {'sequence': 'Profit after taxes for the period was up to EUR0 .9 m , from EUR0 .01 m last year .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.8045114278793335, 0.12049758434295654, 0.07499097287654877]},
#  {'sequence': 'Deliveries have started and the network will be ready for a launch soon .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.7937013506889343, 0.10841172933578491, 0.09788686782121658]},
#  {'sequence': '( ADP News ) - Feb 11 , 2009 - Finnish wood products technology supplier Raute Oyj ( HEL : RUTAV ) said today its net profit decreased to EUR 4.7 million ( USD 6.1 m ) for 2008 from EUR 6.6 million for 2007 .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.856074333190918, 0.0850919634103775, 0.05883372575044632]},
#  {'sequence': 'Under the rental agreement , Stockmann was committed to invest in the building of a bridge over the Gogol Street or build an underground tunnel for crossing the street by 2004 .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.49937185645103455, 0.34383425116539, 0.15679384768009186]},
#  {'sequence': "Finnish electronics manufacturer PKC Group Oyj ( OMX Helsinki : PKC1V ) said on Wednesday ( 31 December ) that it has completed the acquisition of MAN Nutzfahrzeuge AG 's cable harness business from MAN Star Trucks & Buses Spolka zoo in Poland .",
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.4892737865447998, 0.3009761869907379, 0.20975005626678467]},
#  {'sequence': "This new deal has strengthened the partnership from Telemig Celular and Tecnomen , which it has started since the beginning of Telemig 's prepaid operations .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9701887369155884, 0.01872832700610161, 0.011082932353019714]},
#  {'sequence': 'The company has 120 employees and annual sales of approximately EUR16m .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.6629030704498291, 0.20901136100292206, 0.12808555364608765]},
#  {'sequence': "`` After a long , unprofitable period the Food Division posted a profitable result , which speaks of a healthier cost structure and a new approach in business operations , '' Rihko said .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9085680842399597, 0.05684587359428406, 0.034586042165756226]},
#  {'sequence': "An audio webcast will be available live and archived on Cerner 's Web site at www.cerner.com .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.5503730177879333, 0.22957904636859894, 0.22004789113998413]},
#  {'sequence': 'Earnings per share ( EPS ) for the first quarter 2007 amounted to EUR0 .07 , up from EUR0 .04 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.5808935761451721, 0.23374015092849731, 0.18536630272865295]},
#  {'sequence': 'Finnish beverage company Olvi is one of the last listed companies in Finland that has not yet published its financial result for the second quarter of 2009 .',
#   'labels': ['neutral', 'negative', 'positive'],
#   'scores': [0.43258535861968994, 0.3912298381328583, 0.17618486285209656]},
#  {'sequence': "Lassila & Tikanoja 's operating profit excluding non-recurring and imputed items for the second quarter was EUR11 .3 m , down from EUR13 .8 m a year ago .",
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.778081476688385, 0.11677660048007965, 0.10514192283153534]},
#  {'sequence': "Jun. 14 , 2009 ( AOL Weblogs delivered by Newstex ) -- Looks like the E71 is about to be upstaged as Nokia 's ( NYSE : NOK ) premier business-class smartphone -- someone in Espoo 's just hit the corporate YouTube account with this promo video for an E72 .",
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.5131500959396362, 0.2492101937532425, 0.23763974010944366]},
#  {'sequence': 'Finnish Ahlstrom Corporation has ordered key production equipment for a new glass nonwovens production line at its Russian Tver Mill from Finnish Vaahto Pulp & Paper Machinery ( that is part of Vaahto Group ) .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.6419551968574524, 0.19530750811100006, 0.16273730993270874]},
#  {'sequence': 'The business transfer will take effect from 1 January 2007 , and in connection with this 47 employees will transfer from Elisa to Daxtum as continuing employees .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.5058708190917969, 0.27544304728507996, 0.21868614852428436]},
#  {'sequence': 'Janno Reiljan , a member of the Eesti Energia supervisory board , said the owners of Narva Power Grid had informed Eesti Energia about their wish to sell .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.6640272736549377, 0.1915118247270584, 0.14446093142032623]},
#  {'sequence': 'Both operating profit and turnover for the three-month period increased , respectively from EUR0 .9 m and EUR8 .3 m , as compared to the corresponding period in 2005 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9605876207351685, 0.02554137632250786, 0.013870971277356148]},
#  {'sequence': 'Operating profit decreased to EUR 16mn from EUR 21.1 mn in 2008 .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9405651688575745, 0.05065464973449707, 0.008780168369412422]},
#  {'sequence': 'A new Kveyt light variety of Suomalainen Pekoni marketed under the Atria brand name is now available to consumers in Finland .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.6986965537071228, 0.22895123064517975, 0.07235223054885864]},
#  {'sequence': 'Sales at the Tiimari business went down by 8 % to EUR 11.8 million , while Gallerix stores saw 29 % growth to EUR 2 million .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9380190372467041, 0.0311169121414423, 0.030864080414175987]},
#  {'sequence': 'Aspocomp intends to set up a plant to manufacture printed circuit boards with an investment of Rs310 crore .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.7437261343002319, 0.14946356415748596, 0.1068103164434433]},
#  {'sequence': 'The StoneGate product family was designed to provide the full benefits of a unified management system including shared logging , reporting and auditing .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.8081499338150024, 0.11869246512651443, 0.07315756380558014]},
#  {'sequence': '`` We are pleased to welcome Tapeks Noma into Cramo group .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9440954327583313, 0.04016658291220665, 0.015738047659397125]},
#  {'sequence': 'Changes to the as-built models from the design were communicated to the subcontractors to accommodate them into the steel and GRC fabrication process .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.3951336443424225, 0.32222333550453186, 0.28264302015304565]},
#  {'sequence': "Viking Line 's cargo revenue increased by 5.4 % to EUR 21.46 mn , and cargo volume increased by 2.4 % to 70,116 cargo units .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9657884836196899, 0.02007840760052204, 0.014133092947304249]},
#  {'sequence': 'The transaction is subject to a final agreement between the parties , approvals of their decision-making bodies and approval by the Finnish Competition Authority .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.4036993086338043, 0.3717877268791199, 0.2245129495859146]},
#  {'sequence': 'The EBRD is using its own funds to provide a 21.6 million A loan while the B portion of 10 million Euros has been syndicated to two Finnish commercial banks , Nordea Bank Finland Plc and Pohjola Bank Plc. .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.44899410009384155, 0.40804195404052734, 0.1429639458656311]},
#  {'sequence': 'Digia said its consolidated net sales for January-June 2010 were EUR67 .8 m , up 9.7 % on the same period in 2009 ( EUR61 .9 m ) .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.8311570286750793, 0.1291554868221283, 0.039687514305114746]},
#  {'sequence': 'The value of the order is EUR 700,000 .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.7473728656768799, 0.19087886810302734, 0.0617481954395771]},
#  {'sequence': 'Finnish security and privacy software solutions developer Stonesoft Oyj said on January 7 , 2008 that the preliminary sales of its StoneGate products grew by 59 pct year-on-year to 3.6 mln euro ( $ 5.3 mln ) for the fourth quarter of 2007 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.8650768399238586, 0.09824760258197784, 0.036675553768873215]},
#  {'sequence': 'The value of the order is nearly EUR400m .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.81478351354599, 0.09525060653686523, 0.08996587246656418]},
#  {'sequence': "STOCKMANN plc COMPANY ANNOUNCEMENT February 20 , 2007 , at 13.40 An annual summary of Stockmann 's stock exchange and financial press releases in 2006 is available on the company 's website at the address www.stockmann.com .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.4554690718650818, 0.32289618253707886, 0.22163474559783936]},
#  {'sequence': '( ADP News ) - Feb 11 , 2009 - Finnish management software solutions provider Ixonos Oyj ( HEL : XNS1V ) said today its net profit rose to EUR 3.5 million ( USD 4.5 m ) for 2008 from EUR 3.1 million for 2007 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.7414326071739197, 0.17990706861019135, 0.07866028696298599]},
#  {'sequence': "` It is a testament to the quality of our LTE solution and our commitment to the Japanese market ' , he added .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.990934431552887, 0.006806084420531988, 0.0022594998590648174]},
#  {'sequence': "Nokia - the world 's largest mobile phone manufacturer - and China Postel - China 's largest mobile phone distributor - have a long-standing partnership that continues to grow stronger over time .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9580521583557129, 0.026793889701366425, 0.015153909102082253]},
#  {'sequence': "Finnish forest machinery manufacturer Ponsse 's net sales grew to EUR 51.3 mn in the first quarter of 2010 from EUR 37.5 mn in the corresponding period in 2009 .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9559746980667114, 0.02919756807386875, 0.014827747829258442]},
#  {'sequence': 'The contract is worth some EUR 1 million .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.774681806564331, 0.14418527483940125, 0.0811329334974289]},
#  {'sequence': 'In 2010 , the Marimekko Group s net sales were EUR 73,297 thousand ( EUR 72,473 thousand ) and operating profit was EUR 8,169 thousand ( EUR 6,291 thousand ) .',
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.5691106915473938, 0.34653300046920776, 0.08435629308223724]},
#  {'sequence': 'Curators have divided their material into eight themes .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.426541805267334, 0.3418976366519928, 0.23156051337718964]},
#  {'sequence': 'PGE Belchatow runs the 4.44 GW Belchatow coal-fired power plant , and Fortum has intentions to start a CCS demonstration project jointly with Teollisuuden Voima Oyj ( TVO ) - another Finnish utility - at the their jointly owned 565MW Meri-Pori coal-fired facility .',
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.4157619774341583, 0.40993940830230713, 0.17429867386817932]},
#  {'sequence': 'Operating loss totalled EUR 12.7 mn , compared to a profit of EUR 17.7 mn in the first half of 2008 .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9711873531341553, 0.01844998076558113, 0.010362689383327961]},
#  {'sequence': "17 March 2011 - Goldman Sachs estimates that there are negative prospects for the Norwegian mobile operations of Norway 's Telenor ASA OSL : TEL and Sweden 's TeliaSonera AB STO : TLSN in the short term .",
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9902244806289673, 0.0053665051236748695, 0.004408980254083872]},
#  {'sequence': "Liora 's got a brand-new bag .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.895496666431427, 0.055320531129837036, 0.04918287694454193]},
#  {'sequence': 'The Filter Tips cover the volume range from 0.1-1200 -ðl including new sizes for 10 , 20 , 100-120 , 200 , 300 , 1000 and 1200 -ðl volume capacities .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.3938889801502228, 0.3150698244571686, 0.29104122519493103]},
#  {'sequence': "In Finland , OP-Pohjola 's staff union is boycotting the group 's insurance sales tasks because the company has refused to take the sale of insurance into account in determining wages .",
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9482882618904114, 0.03247574716806412, 0.019235989078879356]},
#  {'sequence': "Following the divestment , Fiskars 's Outdoor unit will comprise the brands Gerber , Silva and Buster , and will focus on multi-tools , knives , compasses , mobile lighting , pedometers , and aluminium boats .",
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.4937906265258789, 0.35163193941116333, 0.15457738935947418]},
#  {'sequence': 'Atria Group is a leading Scandinavian meat products group .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.6300501227378845, 0.23288239538669586, 0.1370674967765808]},
#  {'sequence': 'The sale , comprising the margarine business in Finland and Poland , follows the approval of the Polish competition authorities earlier in October .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.6611954569816589, 0.2104884684085846, 0.1283160299062729]},
#  {'sequence': 'In January-June 2010 , diluted loss per share stood at EUR0 .3 versus EUR0 .1 in the first half of 2009 .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9706489443778992, 0.017600875347852707, 0.011750179342925549]},
#  {'sequence': 'Sami Sepp+Ænen , CEO for Elisa Eesti , says the novel network allows fast mobile broadband for sparsely populated areas .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.8012653589248657, 0.1291750818490982, 0.0695594921708107]},
#  {'sequence': 'It operates under three distinct brands : United Supermarkets , Market Street and United Supermercado .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.5607977509498596, 0.35087212920188904, 0.08833012729883194]},
#  {'sequence': "POYRY PLCCompany Announcement 10 December 2010 at 4.10 p.m. Pursuant to Poyry PLC 's stock option program 2004 , 63 792 new shares of the company have been subscribed since 27 October 2010 with stock options 2004B .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.5011855363845825, 0.2788463234901428, 0.21996814012527466]},
#  {'sequence': 'Ruukki is restructuring commercial and industrial construction operations in pursuit of permanent improvements whilst adjusting operations to market conditions .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.49970242381095886, 0.3059493899345398, 0.19434820115566254]},
#  {'sequence': 'The shops are located in the capital region and the Paijat-Hame region .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.4748525619506836, 0.30249324440956116, 0.22265423834323883]},
#  {'sequence': "The presentation material can be viewed on the company 's website in English after the conference .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.4605984687805176, 0.3693232834339142, 0.17007821798324585]},
#  {'sequence': 'Additionally , the company will use the solutions to automate the preparation of financial statements according to IFRS standard .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.7036773562431335, 0.15489545464515686, 0.14142723381519318]},
#  {'sequence': "`` The acquisition of Elektros Pavara completes KONE 's market expansion strategy in the Baltic Countries .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.885816216468811, 0.06475208699703217, 0.049431733787059784]},
#  {'sequence': 'The company expects to open its first online shop in the US in the summer in 2011 .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.5281136631965637, 0.2380904108285904, 0.23379594087600708]},
#  {'sequence': "The company 's profit totaled Ls 578,100 in H1 2007 , down 30.9 % year-on-year .",
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.960585355758667, 0.029873477295041084, 0.009541166946291924]},
#  {'sequence': 'TELECOMWORLDWIRE-7 April 2006-TJ Group Plc sells stake in Morning Digital Design Oy Finnish IT company TJ Group Plc said on Friday 7 April that it had signed an agreement on selling its shares of Morning Digital Design Oy to Edita Oyj .',
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.4541386067867279, 0.3442162573337555, 0.2016451358795166]},
#  {'sequence': "Nokian Capacitors ' equipment will be used to raise the capacity and reliability of the Indian grid .",
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.8048327565193176, 0.11052270233631134, 0.08464460074901581]},
#  {'sequence': "`` EB Tough VoIP was designed to fulfill the communications needs of military units , and we continue to strive towards achieving that goal , '' Mikko Viitaniemi , EB Elektrobit Defense Products , Wireless Solutions senior manager , said in a statement .",
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.8461029529571533, 0.11302029341459274, 0.04087673872709274]},
#  {'sequence': 'The German company has also signed a code share agreement with another Oneworld member -- American Airlines Inc , part of US-based AMR Corp ( NYSE : AMR ) .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.5406729578971863, 0.2736513018608093, 0.185675710439682]},
#  {'sequence': 'Finnish fibers and plastic products maker Suominen Corporation said its net loss narrowed to 1.6 mln euro $ 2.0 mln in the first nine months of 2006 from 2.16 mln euro $ 2.7 mln in the same period of 2005 .',
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.7496037483215332, 0.16834299266338348, 0.08205326646566391]},
#  {'sequence': "Olvi 's target is to strengthen its market share in soft drinks , mineral waters , ciders , long drinks , and energy drinks .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.8127037286758423, 0.104525625705719, 0.0827706903219223]},
#  {'sequence': "Danske Bank is Denmark 's largest bank with 3.5 million customers .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.4946625232696533, 0.264082670211792, 0.24125482141971588]},
#  {'sequence': 'EQT has completed its exit from Salcomp , a Finnish company that makes mobile phone chargers , by selling its remaining stake to Swedish investment group Nordstjernan for about ( EURO ) 35 million ( $ 47 million ) .',
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.6349626779556274, 0.23998679220676422, 0.12505057454109192]},
#  {'sequence': "Both Mr Walden and Mr Ignatius will be responsible also for the newspapers ' business result .",
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.5240174531936646, 0.30904775857925415, 0.1669347584247589]},
#  {'sequence': "TN means that the handset supports TeliaSonera 's Telia Navigator global positioning system service .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.6262844204902649, 0.2397642433643341, 0.1339513659477234]},
#  {'sequence': "According to Finnish financial services group Sampo 's CEO , Bj+¦rn Wahlroos , Danish Danske Bank 's acquisition of Sampo Bank for EUR 4bn was the largest cash deal in Finland 's economic history .",
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.43926817178726196, 0.3231305181980133, 0.23760128021240234]},
#  {'sequence': "`` I 'm happy with the outcome , '' Sneed said after the hearing .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9317857027053833, 0.054420776665210724, 0.013793458230793476]},
#  {'sequence': 'However , the growth margin slowed down due to the financial crisis .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.7013069987297058, 0.2183169424533844, 0.08037607371807098]},
#  {'sequence': 'Vacon aims to establish its presence in the solar energy business in various parts of the world towards the end of 2010 , said Olli Teva , marketing director renewable energy applications .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.8055961728096008, 0.11743076145648956, 0.07697305083274841]},
#  {'sequence': "`` BasWare 's product sales grew strongly in the financial period , by 24 percent .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9546555280685425, 0.03099197894334793, 0.014352468773722649]},
#  {'sequence': 'Secure your files online Like filling out a tax return , making a backup is boring .',
#   'labels': ['neutral', 'negative', 'positive'],
#   'scores': [0.5969944000244141, 0.3678012192249298, 0.03520432487130165]},
#  {'sequence': "Frost sold shares for $ 19 million at $ 6.06-7 .12 per share , compared with Friday 's high of $ 11.33 and low of $ 10.14 .",
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.8378554582595825, 0.10213164985179901, 0.06001283973455429]},
#  {'sequence': 'The six breweries recorded a 5.2 percent growth in domestic beer sales last year to 270.21 million liters , from 256.88 million liters sold in 2005 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.8070579171180725, 0.13113926351070404, 0.06180281192064285]},
#  {'sequence': 'Finnair expands : Finnair plans to add more flights on routes to Hong Kong , India and Russia .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9041635990142822, 0.06975557655096054, 0.026080800220370293]},
#  {'sequence': 'The output of the contracts totals 72 MWe .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.5230110883712769, 0.2781878113746643, 0.198801189661026]},
#  {'sequence': 'Tiimari , the Finnish retailer , reported to have geenrated quarterly revenues totalling EUR 1.3 mn in the 4th quarter 2009 , up from EUR 0.3 mn loss in 2008 .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.9011874198913574, 0.06302270293235779, 0.03578989580273628]},
#  {'sequence': 'The prices of stainless steel also rose in Europe .',
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.44255325198173523, 0.36801356077194214, 0.1894332766532898]},
#  {'sequence': 'KESKO CORPORATION STOCK EXCHANGE RELEASE 28.02.2008 AT 09.30 1 ( 1 ) Kesko Corporation and Aspo plc today signed an agreement by which Aspo acquires the share capital of Kauko-Telko Ltd , a subsidiary wholly owned by Kesko .',
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.4196096360683441, 0.3947349190711975, 0.18565545976161957]},
#  {'sequence': 'The period-end cash and cash equivalents totaled EUR6 .5 m , compared to EUR10 .5 m in the previous year .',
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.8373280167579651, 0.0848512277007103, 0.07782075554132462]},
#  {'sequence': 'However short-term rentals are becoming more popular .',
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.3773649036884308, 0.3463958203792572, 0.2762392461299896]},
#  {'sequence': 'Pharmaceutical market in Belgium Global Research & Data Services published recently a market analysis about the pharmaceutical markets in Belgium .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.4797804355621338, 0.39585644006729126, 0.12436313927173615]},
#  {'sequence': 'Based on the 2005 calendar year the combined company had EUR15 .8 bn in pro forma annual revenues and is expected to start operations with 60,000 employees .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.5609378218650818, 0.2599245309829712, 0.17913764715194702]},
#  {'sequence': 'The money will be spread mainly over 2011 and 2012 , the company said .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.3964969217777252, 0.31817901134490967, 0.2853240668773651]},
#  {'sequence': 'The lay-offs will affect 240 people out of the total 320 Okmetic employees in Finland .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9252353310585022, 0.05664693936705589, 0.01811775006353855]},
#  {'sequence': 'In January-September 2007 , operating profit totaled EUR 20.5 mn .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.6517761945724487, 0.19704031944274902, 0.15118353068828583]},
#  {'sequence': 'The annual Thesis contest is aimed to enhance the thesis quality and to strengthen the thesis culture in polytechnics .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.8821795582771301, 0.07309015840291977, 0.044730331748723984]},
#  {'sequence': "Finnish Cargotec 's Kalmar has received a significant order from the US Department of Defense .",
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.8708067536354065, 0.08906912803649902, 0.04012412950396538]},
#  {'sequence': 'Water Treatment Products In Australia Today , Global Research & Data Services is going to publish a market analysis about the market for chemical water treatment products in Australia .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.5081145167350769, 0.37261462211608887, 0.11927088350057602]},
#  {'sequence': 'Construction is expected to be completed in the summer of 2011 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.40329891443252563, 0.3010985255241394, 0.29560256004333496]},
#  {'sequence': "Den Bosch-based TomTom is Europe 's largest maker of automotive navigation devices , while Cayman Islands-based Garmin is larger in the U.S. and overall .",
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.5501225590705872, 0.2841314971446991, 0.16574594378471375]},
#  {'sequence': 'According to the Latvian business register , Uponor Latvia closed in red with LVL 99,000 EUR 139,538.17 USD 194,556.48 on turnover of LVL 2.346 mn for 2009 .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9913814067840576, 0.006509367376565933, 0.0021093005780130625]},
#  {'sequence': 'By acquiring RCP , we can combine our strong knowhow with the expertise of a solid local company .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9090876579284668, 0.06614693999290466, 0.02476543001830578]},
#  {'sequence': 'Finnish business software group AffectoGenimap Oyj said it had signed an agreement to acquire all the shares in Swedish sector company Intellibis Ab for 12 mln euro ( $ 15.8 mln ) on a debt-free basis .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.6134063601493835, 0.21145983040332794, 0.17513376474380493]},
#  {'sequence': 'TeliaSonera has secured deliveries for 4G modems with support for 3G and 2G during the second quarter 2010 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.737358570098877, 0.15216171741485596, 0.1104796826839447]},
#  {'sequence': 'Finnish glass technology group Glaston Corporation ( OMX Helsinki : GLA1V ) reported on Thursday ( 14 August ) an operating profit of EUR6 .5 m on net sales of EUR201 .5 m for the period January-September 2008 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.47063368558883667, 0.26726576685905457, 0.26210057735443115]},
#  {'sequence': "The airline 's share price closed down slightly at (  x20ac ) 12.51 ( $ 15US .74 ) in Helsinki .",
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.7257729768753052, 0.15232737362384796, 0.12189965695142746]},
#  {'sequence': "We are very excited working with Maxis on this first commercial deployment of ` Master of Maya ' , said Joe Doering , Head of the Asia South region at Nokia Siemens Networks .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9446200132369995, 0.03432324156165123, 0.021056726574897766]},
#  {'sequence': 'Pharmaceuticals - Netherlands This brand-new market analysis gives a clear overview of the actual situation and future outlook of the pharmaceutical market in Netherlands .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.6067732572555542, 0.3176557123661041, 0.07557108253240585]},
#  {'sequence': "Elcoteq 's revenues in 2007 were approximately EUR 120 million .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.6911048293113708, 0.15799835324287415, 0.15089687705039978]},
#  {'sequence': 'In Q2 of 2009 , profit before taxes amounted to EUR 13.6 mn , down from EUR 26.8 mn in Q2 of 2008 .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9383120536804199, 0.05116063728928566, 0.010527362115681171]},
#  {'sequence': 'Founded in 1946 , Strand Associates , which provides civil , environmental , transportation , electrical and mechanical engineering services , has 350 employees at 10 offices in Wisconsin , Alabama , Illinois , Indiana , Kentucky and Ohio .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.5977252721786499, 0.23841112852096558, 0.16386353969573975]},
#  {'sequence': "South African Sappi will become the largest foreign forest industry company operating in Finland as a result of the acquisition Finnish M-real Corporation 's Graphic Papers Business unit .",
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.6096308827400208, 0.2582179605960846, 0.13215118646621704]},
#  {'sequence': 'According to Finnish pension insurance company Varma , Varma was the recipient of over two thirds of the revenue of the earnings-related pension cover that was under competitive tendering in Finland .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.5354489684104919, 0.2843058407306671, 0.18024522066116333]},
#  {'sequence': 'Particular attention is being paid to energy efficiency in the construction of the building , as it is designed to meet the requirements of energy class B , and LEED certification will be applied for .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.8481558561325073, 0.08491714298725128, 0.06692700833082199]},
#  {'sequence': 'Raute Corporation has received orders worth over EUR 12 million from OOO Ilim Bratsk DOK in Russia .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.76203453540802, 0.12593427300453186, 0.11203114688396454]},
#  {'sequence': 'Private equity investor CapMan , the owner of Finnish Lumene cosmetics company , is planning to list Lumene .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.6426314115524292, 0.1878063976764679, 0.16956216096878052]},
#  {'sequence': 'It estimates the operating profit to further improve from the third quarter .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9268216490745544, 0.06170576065778732, 0.011472547426819801]},
#  {'sequence': 'LONDON ICIS -- Tikkurila has completed the sale of its powder coatings business to Finnish industrial coatings firm Teknos Group , the Finland-based decorative paints company said on Wednesday .',
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.538860023021698, 0.29662299156188965, 0.16451700031757355]},
#  {'sequence': "The Basware Connectivity services allow companies to handle purchase to pay processes online and make their internal processes more efficient , '' said CEO Ilkka Sihvo , Basware Corporation .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.8847165107727051, 0.08913043141365051, 0.02615305595099926]},
#  {'sequence': 'Iggesunds Bruk in Sweden is one of the most advanced , fully integrated pulp and paperboard mills in the world .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.7242193222045898, 0.15915924310684204, 0.11662140488624573]},
#  {'sequence': 'According to product manager Lassi Hietanen , building a power plant that burns mixed waste in Helsinki may not be a good idea because this reduces the production of combined power plants using natural gas .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9661245942115784, 0.02026929147541523, 0.013606139458715916]},
#  {'sequence': 'The natural source of isoprene is the tree species Hevea brasiliensis , also known as the rubber tree .',
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.45929548144340515, 0.41324082016944885, 0.1274636685848236]},
#  {'sequence': 'Operating profit rose to EUR 27.8 mn from EUR 17.5 mn in 2008 .',
#   'labels': ['positive', 'neutral', 'negative'],
# ...
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.40443533658981323, 0.3525332510471344, 0.24303139746189117]},
#  {'sequence': 'The scope of the project is to find the most cost-efficient method for phosphorous removal and to deliver the storing and dosing equipment , which can be used in continuous operation at the plants .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.5292779803276062, 0.37225356698036194, 0.09846846014261246]},
#  {'sequence': 'Jussi Pesonen , member of the Sampo Board since 2006 , will renounce his seat in Sampo Board .',
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.7653448581695557, 0.14540214836597443, 0.0892530232667923]},
#  {'sequence': "The subscriptions increase Cargotec 's share capital by EUR 27,060 .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9048015475273132, 0.057142604142427444, 0.038055870682001114]},
#  {'sequence': 'No financial details were revealed .',
#   'labels': ['neutral', 'negative', 'positive'],
#   'scores': [0.6988630890846252, 0.23867858946323395, 0.06245838478207588]},
#  {'sequence': 'Master of Mayawas jointly developed by Nokia Siemens Networks and UFA - FremantleMedia , and will be actively advertised by Maxis in the end of May 2007 .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.6099880337715149, 0.2513209283351898, 0.13869109749794006]},
#  {'sequence': 'Asian traffic declined by 3.4 per cent .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9516772031784058, 0.030896876007318497, 0.01742595061659813]},
#  {'sequence': 'Analysts surveyed by Thomson Financial expected revenue of $ 69 million for the quarter .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.44339612126350403, 0.3270632326602936, 0.2295406460762024]},
#  {'sequence': "The economic occupancy rate of Sponda 's property portfolio rose to 91.2 % from 88.8 % in 2006 .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9203162789344788, 0.05228305980563164, 0.02740064263343811]},
#  {'sequence': "It delivers a different user experience and enables us to widen the market we can address . ''",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9877122640609741, 0.009471056051552296, 0.002816753927618265]},
#  {'sequence': 'Componenta will also offer a five-year subordinated loan for subscription by the public .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.535912275314331, 0.27093398571014404, 0.19315379858016968]},
#  {'sequence': 'Diluted EPS rose to EUR3 .68 from EUR0 .50 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.769978940486908, 0.16935233771800995, 0.06066872924566269]},
#  {'sequence': 'HELSINKI ( AFX ) - Retail and wholesale group Kesko reported net sales of 659.4 mln eur for February , an increase of 10.8 pct year-on-year .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.7931270003318787, 0.1495167315006256, 0.0573563277721405]},
#  {'sequence': 'Vacon controls a further 5 % of the company via investment fund Power Fund I. EUR 1.0 = USD 1.397',
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.5080069899559021, 0.3464904725551605, 0.14550255239009857]},
#  {'sequence': 'Finnish energy company Fortum has set itself new stricter target limits for short-term carbon dioxide emissions from its heat and electricity production .',
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.6555518507957458, 0.27026739716529846, 0.0741807371377945]},
#  {'sequence': 'Our customers come from the following countries : UK , USA , Spain , France , Italy , Germany , China , Sweden , Norway , Netherlands , Austria , Belgium , Switzerland , Czech Republic , Serbia , Finland , Canada , Russia , Ukraine , Portugal , Denmark , Ireland , South Korea , Estonia and Liechtenstein .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.8282169699668884, 0.09503456205129623, 0.07674845308065414]},
#  {'sequence': 'The value of the orders is about EUR 70mn .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.7488467693328857, 0.14684775471687317, 0.10430541634559631]},
#  {'sequence': 'Patrick Jeambar will also continue being responsible for Innovation and Health , safety and environment HSEA functions of Ahlstrom Corporation .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.4394145607948303, 0.30551978945732117, 0.2550656199455261]},
#  {'sequence': 'The new B shares carry the right to dividend and other shareholder rights with effect from today .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.7074205279350281, 0.2039620578289032, 0.08861736208200455]},
#  {'sequence': "This new representation extends Comptel 's global presence to a total of 18 countries , serving over 250 customers in over 80 countries worldwide .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.8416198492050171, 0.09642082452774048, 0.06195925176143646]},
#  {'sequence': 'The name of the newspaper publishing and printing division Sanoma will be changed to Sanoma News .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.4694541096687317, 0.28088492155075073, 0.24966087937355042]},
#  {'sequence': 'The fourth quarter saw Rapala swing back to a pretax profit of 1.5 mln eur from a year earlier loss of 1.2 mln on the back of a 30 pct uplift in sales to 44.8 mln eur , and a stronger performance in North America .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9106419086456299, 0.05885476991534233, 0.030503258109092712]},
#  {'sequence': "Another noticeable thing is that the search for Tata and Airtel brands was mostly related to ` broadband connections ' .",
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.4865180253982544, 0.34095513820648193, 0.1725267916917801]},
#  {'sequence': 'Both operating profit and net sales for the six-month period increased , respectively from EUR18 .1 m and EUR127 .6 m , as compared to the corresponding period in 2006 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9598031640052795, 0.026882672682404518, 0.013314170762896538]},
#  {'sequence': 'Currently the quarterly applied surcharges differ significantly from the actual market prices .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.6501261591911316, 0.2114104926586151, 0.1384633481502533]},
#  {'sequence': 'The company said Offshore segment represented 43 % of the total marine engines orders for the July-September 2010 period , Merchant 33 % , Special vessels 18 % , and Cruise and Ferry , and Ship Design -- 2 % and 3 % , respectively .',
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.5193638205528259, 0.29544222354888916, 0.18519392609596252]},
#  {'sequence': "The Finnish paints company acquired the remaining 49 pct that it did not own from Ukraine 's LGU for an undisclosed sum .",
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.45350995659828186, 0.3541305959224701, 0.19235947728157043]},
#  {'sequence': 'The purchase price was not disclosed .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.48215365409851074, 0.27698126435279846, 0.2408650815486908]},
#  {'sequence': "Furthermore , efficiency improvement measures initiated earlier are now bearing fruit , '' CEO Jan Lang said .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9802230000495911, 0.015207720920443535, 0.00456922547891736]},
#  {'sequence': 'The value of the deal has not been disclosed .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.4866064190864563, 0.33415430784225464, 0.17923931777477264]},
#  {'sequence': "Moreover , Konecranes and Kito intend to transfer the hoist distribution business of Konecranes ' Japanese joint venture MHS Konecranes to Kito .",
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.6596719622612, 0.24676242470741272, 0.09356559813022614]},
#  {'sequence': '( I&H ) in a move to enhance growth .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.94596266746521, 0.03548889234662056, 0.018548503518104553]},
#  {'sequence': 'Operating loss totalled EUR 3.2 mn , compared to a profit of EUR 7.2 mn in the third quarter of 2008 .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9788522124290466, 0.01378861628472805, 0.007359152659773827]},
#  {'sequence': 'The contract traded at an all-time high of $ 50,200 a ton on April 24 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.6544753909111023, 0.2137567400932312, 0.13176791369915009]},
#  {'sequence': 'In addition , Kone signed a two-year maintenance contract for the escalators .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.7055602073669434, 0.16610543429851532, 0.1283344179391861]},
#  {'sequence': 'One can also apply for jobs directly from the iPad , select which CV to attach and which covering letter is most appropriate for each position .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.495909184217453, 0.29144811630249023, 0.21264268457889557]},
#  {'sequence': 'The combination of all services enabling us to offer a complex and strengthened service chain not only limited to the Baltic port connections but also for getting access to the world wide Grimaldi Network into the Mediterranean , Africa and North America `` says Uwe Bakosch .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9057577848434448, 0.07056371122598648, 0.023678500205278397]},
#  {'sequence': 'Union and company officials did not return calls yesterday .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.8372756838798523, 0.10439466685056686, 0.05832967907190323]},
#  {'sequence': 'Turun kaupunkin , Finland based company has awarded contract to Lemminkainen Talotekniikka Oy for electrical installation work .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.6434113383293152, 0.19689960777759552, 0.1596890389919281]},
#  {'sequence': 'ALEXANDRIA , Va. , Nov. 19 -- Erkki Aho , Elimaki , Finland , has developed a method and apparatus in conjunction with a shoe press .',
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.36158934235572815, 0.32605159282684326, 0.3123590350151062]},
#  {'sequence': 'ADPnews - Jul 17 , 2009 - Finland-based steel maker Rautaruukki Oyj Ruukki HEL : RTRKS said today it slipped to a net loss of EUR 184 million USD 259.7 m for the first half of 2009 from a net profit of EUR 2',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.972654402256012, 0.016547322273254395, 0.010798285715281963]},
#  {'sequence': "In addition , the Kazakh delegation will visit Finland 's SITRA investment fund , Honkarakenne Ltd and Nokia headquarters to study TeliaSonera Ltd JSC 's activities .",
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.6138012409210205, 0.2027662843465805, 0.18343251943588257]},
#  {'sequence': 'Rapala VMC Corporation ( Rapala ) is a Finland-based company engaged in the manufacture and distribution of fishing equipment and accessories .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.4096578359603882, 0.31799590587615967, 0.27234625816345215]},
#  {'sequence': 'Lean System supports change management and component purchasing extremely well .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9555772542953491, 0.03362859785556793, 0.010794109664857388]},
#  {'sequence': 'Yvonne Jones is owner of Chameleon Interiors .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.5780050754547119, 0.2610384523868561, 0.160956472158432]},
#  {'sequence': 'Sales rose 10 pct to 566 mln eur on the back of strong volume and favourable currency effects .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.934598445892334, 0.04947270452976227, 0.0159288439899683]},
#  {'sequence': 'According to Ultrascan , with a software acquired from crackers , it has managed to change the mobile phone in a way that the phone was able to get hold of a one-time password sent by a bank via a text message .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.5050396919250488, 0.2756781578063965, 0.21928218007087708]},
#  {'sequence': 'However , two of the previously ordered sets will start producing electricity at the end of October 2010 , it said .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.716843843460083, 0.14918412268161774, 0.13397203385829926]},
#  {'sequence': 'A realignment of interests in the sector is clearly under way .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.9334592223167419, 0.037665095180273056, 0.02887572906911373]},
#  {'sequence': 'Therefore , Phase III of the research will not be conducted by Abbott .',
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.9406859278678894, 0.03028399683535099, 0.02903011627495289]},
#  {'sequence': 'Profit before taxes amounted to EUR 56.5 mn , down from EUR 232.9 mn a year ago .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.885107159614563, 0.09096071124076843, 0.023932121694087982]},
#  {'sequence': 'Citigroup , Inc ( NYSE : C ) has announced that its Global Transaction Services ( GTS ) business has been awarded a new mandate by Finland-based Pohjola Bank Group .',
#   'labels': ['positive', 'negative', 'neutral'],
#   'scores': [0.7245537042617798, 0.1617017537355423, 0.11374453455209732]},
#  {'sequence': "Investors will continue being interested in the company 's share although it is not quite cheap , Affarsvarlden said .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.7724387049674988, 0.17098520696163177, 0.05657608434557915]},
#  {'sequence': 'No more waste-burning facilities should be built .',
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.9373395442962646, 0.05007591471076012, 0.012584522366523743]},
#  {'sequence': "Last month , Outokumpu sold more than 80 percent of its technology unit , Outokumpu Technology Oyj , to further its strategic goal of becoming the world 's largest stainless steel maker .",
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.5207776427268982, 0.33752313256263733, 0.1416991800069809]},
#  {'sequence': 'The actions are expected to deliver annual cost savings of some EUR15-20m .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.8766422867774963, 0.08298929780721664, 0.040368419140577316]},
#  {'sequence': '( ADPnews ) - Dec 30 , 2009 - Finnish investment group Neomarkka Oyj ( HEL : NEMBV ) said today that it will furlough employee in its unit Reka Cables Ltd for less than 90 days , starting in January 2010 .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.7808724641799927, 0.14712482690811157, 0.07200273871421814]},
#  {'sequence': 'The company said that the results of the third quarter do not include non-recurring items .',
#   'labels': ['neutral', 'negative', 'positive'],
#   'scores': [0.5026885271072388, 0.31535932421684265, 0.18195205926895142]},
#  {'sequence': "The equipment will be made at Vaahto 's plant in Hollola in Finland , and delivery is scheduled for the first quarter of 2009 .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.46905970573425293, 0.29894256591796875, 0.23199771344661713]},
#  {'sequence': 'A broad range of connectivity options including 3G - HSPA and Wi-Fi gives consumers high speed access to the Internet .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.8294616937637329, 0.13335731625556946, 0.03718098625540733]},
#  {'sequence': 'Diluted earnings per share ( EPS ) rose to EUR 0.29 from EUR 0.05 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.6828222274780273, 0.27778148651123047, 0.039396267384290695]}]

# %%
# retrieving sentiments
y_pred = [i['labels'][0] for i in y_pred]
y_pred
# Out:
# ['positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'positive']

# %%
# Pre-trained model performance
from sklearn.metrics import accuracy_score, classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.46      0.99      0.63       118
#      neutral       0.88      0.05      0.10       563
#     positive       0.40      0.94      0.56       287
#
#     accuracy                           0.43       968
#    macro avg       0.58      0.66      0.43       968
# weighted avg       0.68      0.43      0.30       968

# %%
# Importing packages for training the model
from datasets import Dataset
from transformers import (
    AutoTokenizer,
    AutoConfig,
    AutoModelForSequenceClassification,
    DataCollatorWithPadding,
    Trainer,
    TrainingArguments,
    pipeline
)
import random

# %%
categories
hypo_template = "This text is {}."

# %%
# NLI labels
label2id = {"CONTRADICTION": 0, "NEUTRAL": 1, "ENTAILMENT": 2}
id2label = {v: k for k, v in label2id.items()}

label2id, id2label
# Out:
# ({'CONTRADICTION': 0, 'NEUTRAL': 1, 'ENTAILMENT': 2},
#  {0: 'CONTRADICTION', 1: 'NEUTRAL', 2: 'ENTAILMENT'})

# %%
text_data = text_data[['text', 'sentiment']]
text_data
# Out:
#                                                    text sentiment
# 0     According to Gran , the company has no plans t...   neutral
# 1     Technopolis plans to develop in stages an area...   neutral
# 2     The international electronic industry company ...  negative
# 3     With the new production plant the company woul...  positive
# 4     According to the company 's updated strategy f...  positive
# ...                                                 ...       ...
# 4841  LONDON MarketWatch -- Share prices ended lower...  negative
# 4842  Rinkuskiai 's beer sales fell by 6.5 per cent ...   neutral
# 4843  Operating profit fell to EUR 35.4 mn from EUR ...  negative
# 4844  Net sales of the Paper segment decreased to EU...  negative
# 4845  Sales in Finland decreased by 10.5 % in Januar...  negative
#
# [4840 rows x 2 columns]

# %% [markdown]
# Creating premises (text), hypothesis (sentiment) and labels (contradiction, entailment, neutral) for all labels

# %%
premises = []
hypotheses = []
nli_labels = []

# %%
for index, row in text_data.iterrows():
    for category in categories:
        if row['sentiment'] == category:
            nli_labels.append(label2id["ENTAILMENT"])
        else:
            nli_labels.append(label2id["CONTRADICTION"])
        premises.append(row['text'])
        hypotheses.append(hypo_template.format(category))
expanded_data = pd.DataFrame({'premise': premises, 'hypothesis': hypotheses, 'nli_label': nli_labels})

# %%
expanded_data
# Out:
#                                                  premise  \
# 0      According to Gran , the company has no plans t...
# 1      According to Gran , the company has no plans t...
# 2      According to Gran , the company has no plans t...
# 3      Technopolis plans to develop in stages an area...
# 4      Technopolis plans to develop in stages an area...
# ...                                                  ...
# 14515  Net sales of the Paper segment decreased to EU...
# 14516  Net sales of the Paper segment decreased to EU...
# 14517  Sales in Finland decreased by 10.5 % in Januar...
# 14518  Sales in Finland decreased by 10.5 % in Januar...
# 14519  Sales in Finland decreased by 10.5 % in Januar...
#
#                    hypothesis  nli_label
# 0       This text is neutral.          2
# 1      This text is positive.          0
# 2      This text is negative.          0
# 3       This text is neutral.          2
# 4      This text is positive.          0
# ...                       ...        ...
# 14515  This text is positive.          0
# 14516  This text is negative.          2
# 14517   This text is neutral.          0
# 14518  This text is positive.          0
# 14519  This text is negative.          2
#
# [14520 rows x 3 columns]

# %%
# no of unique words in data
len(set(' '.join(text_data['text']).split()))
# Out:
# 12971

# %%
# Converting to Dataset class
expanded_ds = Dataset.from_pandas(expanded_data)
expanded_ds
# Out:
# Dataset({
#     features: ['premise', 'hypothesis', 'nli_label'],
#     num_rows: 14520
# })

# %%
# Splitting data
expanded_ds = expanded_ds.train_test_split(test_size=0.2)
expanded_ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['premise', 'hypothesis', 'nli_label'],
#         num_rows: 11616
#     })
#     test: Dataset({
#         features: ['premise', 'hypothesis', 'nli_label'],
#         num_rows: 2904
#     })
# })

# %%
# Tokenizing pair inputs
def tokenize_fn(batch):
    return tokenizer(batch["premise"], batch["hypothesis"], truncation=True, max_length=256)

# %%
# Tokeninizing premise and hypothesis
tokenized = {}
for split in expanded_ds:
    tokenized[split] = expanded_ds[split].map(tokenize_fn, batched=True)
    tokenized[split] = tokenized[split].rename_column("nli_label", "labels")
    tokenized[split].set_format(type="torch", columns=["input_ids", "attention_mask", "labels"])
# Out:
# Map:   0%|          | 0/11616 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2904 [00:00<?, ? examples/s]

# %%
tokenized
# Out:
# {'train': Dataset({
#      features: ['premise', 'hypothesis', 'labels', 'input_ids', 'attention_mask'],
#      num_rows: 11616
#  }),
#  'test': Dataset({
#      features: ['premise', 'hypothesis', 'labels', 'input_ids', 'attention_mask'],
#      num_rows: 2904
#  })}

# %%
# Load model with correct head (3 classes for NLI)
config = AutoConfig.from_pretrained(model_name)

# NLI label space = 3 with MNLI mapping
config.num_labels = 3
config.id2label = id2label
config.label2id = label2id

# %%
# Loading model with config
model = AutoModelForSequenceClassification.from_pretrained(model_name, config=config)

# %%
# Data collator with tokenizer
collator = DataCollatorWithPadding(tokenizer=tokenizer)

# %%
# Training args for tuning
args = TrainingArguments(
    output_dir = "./bart-mnli-sentiment-nli",
    eval_strategy = "steps",
    eval_steps = 500,
    save_steps = 500,
    logging_steps = 100,
    learning_rate = 5e-5,
    per_device_train_batch_size = 8,
    per_device_eval_batch_size = 16,
    num_train_epochs = 5,
    weight_decay = 0.01,
    warmup_ratio = 0.06,
    lr_scheduler_type = "linear",
    save_total_limit = 2,
    load_best_model_at_end = True,
    metric_for_best_model = "eval_loss",
    greater_is_better=False,
    report_to = "tensorboard"
)

# %%
# Creating trainer class
trainer = Trainer(
    model = model,
    args = args,
    train_dataset = tokenized['train'],
    eval_dataset = tokenized['test'],
    processing_class = tokenizer,
    data_collator = collator
)

# %%
# Model training
trainer.train()
# Out:
#     <div>
#
#       <progress value='7260' max='7260' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7260/7260 43:59, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.419700</td>
#       <td>0.507154</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.440700</td>
#       <td>0.584067</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.368300</td>
#       <td>0.371040</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.270200</td>
#       <td>0.469932</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.323200</td>
#       <td>0.333457</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.273900</td>
#       <td>0.374012</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.210700</td>
#       <td>0.307993</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.158800</td>
#       <td>0.284700</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.154500</td>
#       <td>0.304892</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.127200</td>
#       <td>0.238853</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.078700</td>
#       <td>0.208555</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.056200</td>
#       <td>0.195520</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.042000</td>
#       <td>0.178006</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.053300</td>
#       <td>0.179048</td>
#     </tr>
#   </tbody>
# </table><p>
# There were missing keys in the checkpoint model loaded: ['model.encoder.embed_tokens.weight', 'model.decoder.embed_tokens.weight'].
# TrainOutput(global_step=7260, training_loss=0.2326066361971138, metrics={'train_runtime': 2640.6992, 'train_samples_per_second': 21.994, 'train_steps_per_second': 2.749, 'total_flos': 7303440451831776.0, 'train_loss': 0.2326066361971138, 'epoch': 5.0})

# %%
# Saving training model
trainer.save_model("./bart-mnli-sentiment-nli")
tokenizer.save_pretrained("./bart-mnli-sentiment-nli")
# Out:
# ('./bart-mnli-sentiment-nli/tokenizer_config.json',
#  './bart-mnli-sentiment-nli/special_tokens_map.json',
#  './bart-mnli-sentiment-nli/vocab.json',
#  './bart-mnli-sentiment-nli/merges.txt',
#  './bart-mnli-sentiment-nli/added_tokens.json',
#  './bart-mnli-sentiment-nli/tokenizer.json')

# %%
# Loading trained model and creating pipeline
model_dir = "./bart-mnli-sentiment-nli"
model = AutoModelForSequenceClassification.from_pretrained("./bart-mnli-sentiment-nli")
tokenizer = AutoTokenizer
clf = pipeline(
    "zero-shot-classification",
    model=model,
    tokenizer=model_dir,
    hypothesis_template="This text is {}.",  # same as training
)
# Out:
# Device set to use cuda:0

# %%
# Predicting sentiments with new trained model
y_pred = clf(X_test.tolist(), candidate_labels=categories)
y_pred
# Out:
# [{'sequence': 'The company serves customers in various industries , including process and resources , industrial machinery , architecture , building , construction , electrical , transportation , electronics , chemical , petrochemical , energy , and information technology , as well as catering and households .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.999119222164154,
#    0.00044703614548780024,
#    0.0004337694845162332]},
#  {'sequence': 'Officials did not disclose the contract value .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.999083399772644, 0.000461624440504238, 0.00045499575207941234]},
#  {'sequence': 'The extracted filtrates are very high in clarity while the dried filter cakes meet required transport moisture limits (TMLs)for their ore grades .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9979279637336731,
#    0.0014167525805532932,
#    0.0006552419508807361]},
#  {'sequence': 'The tool is a patent pending design that allows consumers to lay out their entire project on a removable plate using multiple clear stamps of any kind .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990928173065186,
#    0.00046139591722749174,
#    0.00044578296365216374]},
#  {'sequence': "In Finland , the corresponding service is Alma Media 's Etuovi.com , Finland 's most popular and best known nationwide online service for home and property sales .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991163015365601,
#    0.00044820457696914673,
#    0.00043553352588787675]},
#  {'sequence': "Sanoma also has an Executive Committee , in accordance with the Company 's Articles of Association , that prepares proposals for matters to be decided or noted by the Board of Directors .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991030097007751,
#    0.00045359853538684547,
#    0.00044345439528115094]},
#  {'sequence': 'Finnish property investment company Citycon plans to issue directed subordinated convertible bonds to institutional investors .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990906715393066,
#    0.00046536445734091103,
#    0.0004439593176357448]},
#  {'sequence': 'The gross area of the Innova 2 project will be about 10,000 sq m ( 107,600 sq ft ) .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991089105606079,
#    0.000448801729362458,
#    0.00044230971252545714]},
#  {'sequence': "Glaston 's own glass processing unit , Tamglass Glass Processing , is a manufacturer of high quality safety glass products , and operates in Finland .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990791082382202,
#    0.00046709750313311815,
#    0.0004537876811809838]},
#  {'sequence': 'Combined net sales in 2006 were $ 27 million and EBITDA was $ 13.7 million .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991129040718079,
#    0.00044446621905080974,
#    0.0004426338418852538]},
#  {'sequence': 'No service pricing details were disclosed .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990836977958679,
#    0.0004598794912453741,
#    0.00045638924348168075]},
#  {'sequence': 'INTERNET BUSINESS NEWS - -_ 1995-2006 M2 COMMUNICATIONS LTD As part of a drive to protect users of its Internet banking service , Barclays Bank has announced that it is to recommend F-Secure Internet Security to its customers .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990889430046082,
#    0.0004653756332118064,
#    0.0004457432369235903]},
#  {'sequence': 'All depends on financing .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990556240081787,
#    0.0004795620625372976,
#    0.0004647978930734098]},
#  {'sequence': "Forestries were also higher , driven by yesterday 's bullish analyst comment on Stora Enso in Dagens Industri , dealers said .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990670680999756,
#    0.0005194272962398827,
#    0.0004135344352107495]},
#  {'sequence': 'In stead of being based on a soft drink , as is usual , the Teho energy drink is made with fresh water .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990419745445251,
#    0.0004905640380457044,
#    0.00046751913032494485]},
#  {'sequence': 'Finnish house manufacturers are targeting the strongly growing one-family house market in Russia .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.998942494392395, 0.0005652936524711549, 0.0004921776126138866]},
#  {'sequence': "Local government commissioner of +_m+_l , Kurt Svensson , says he will contact the management of Finnish company Componenta to find out if there are any alternatives to the company 's decision to close down its plant in +_m+_l .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990946650505066, 0.0004573650367092341, 0.000448035541921854]},
#  {'sequence': "And that 's exactly what happened on a recent weekday when an East Haven baker was brought in to remind residents about the Easter tradition of making wheat and rice pies .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990839958190918,
#    0.00046471261885017157,
#    0.0004513175808824599]},
#  {'sequence': 'Following the increase the company+ˆEUR TM s capital totals 5.5 mln Romanian lei $ 1.98 mln-1 .56 mln euro .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.99907386302948, 0.00046822053263895214, 0.0004579299711622298]},
#  {'sequence': 'Net sales will , however , increase from 2005 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990889430046082,
#    0.0005010874010622501,
#    0.00040996208554133773]},
#  {'sequence': 'The insurance division turned a EUR120m profit .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990792274475098,
#    0.0004668418550863862,
#    0.0004539233341347426]},
#  {'sequence': "At 10.33 am , Huhtamaki was the market 's biggest faller , 8.69 pct lower at 11.35 eur , while the OMX Helsinki 25 was 0.32 pct higher at 3,332.41 , and the OMX Helsinki was up 0.47 pct at 11,687.32 .",
#   'labels': ['neutral', 'negative', 'positive'],
#   'scores': [0.3949345052242279, 0.31064680218696594, 0.29441866278648376]},
#  {'sequence': 'Operating profit rose to EUR 13.1 mn from EUR 8.7 mn in the corresponding period in 2007 representing 7.7 % of net sales .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990894198417664,
#    0.0004830367397516966,
#    0.0004275932733435184]},
#  {'sequence': 'The copying , republication or redistribution of AFX News Content , including by framing or similar means , is expressly prohibited without the prior written consent of AFX News .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991053342819214,
#    0.0004481504438444972,
#    0.00044652505312114954]},
#  {'sequence': 'The Web-Marela application handles invitations to quote , quote comparisons , agreements , purchases , invoice inspections , inventory management , and deliveries .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.999122142791748,
#    0.00044232490472495556,
#    0.00043549263500608504]},
#  {'sequence': 'Kesko offers Hilton to open a hotel on Kalinisky prospect in a 18,000-square metres building because of these difficulties .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9927013516426086, 0.006539165508002043, 0.0007595019415020943]},
#  {'sequence': 'Finland-based international machinery rental company Ramirent Plc ( OMX Helsinki : RMR1V ) said on Friday ( 9 May ) that its president and CEO , Kari Kallio , has informed the board of his intention to retire in year 2009 .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991168975830078,
#    0.00044775803689844906,
#    0.00043542805360630155]},
#  {'sequence': "The reasons behind the estimate include the rise in 2008 rent levels and several fully-leased office and retail properties , which were completed and added to the company 's investment property portfolio .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9973609447479248,
#    0.0020374769810587168,
#    0.0006015035905875266]},
#  {'sequence': "Image data produced by the browser at the phone server is converted into a bitmapped image that is sent to the handset for display . ''",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991088509559631,
#    0.00044656312093138695,
#    0.00044456179603002965]},
#  {'sequence': 'Based on the design of previous handsets , the Nokia E72 and Nokia E63 this Symbian-based model is promised to offer direct access to over 90 per cent of the world s corporate email through Mail for Exchange and IBM Lotus Notes Traveler .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990655183792114,
#    0.0004840181500185281,
#    0.0004504572134464979]},
#  {'sequence': 'Rental of building equipment accounted for 88 percent of the operating income .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990934133529663,
#    0.0004596036160364747,
#    0.0004470063140615821]},
#  {'sequence': 'Following the registration , the share capital of Biotie is EUR 52,556,678.10 .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990905523300171,
#    0.0004576534847728908,
#    0.0004518589994404465]},
#  {'sequence': 'The goal will be achieved via organic growth possibly supplemented by acquisitions .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9986888766288757,
#    0.0008079941035248339,
#    0.0005030499887652695]},
#  {'sequence': 'Revenue was slightly down , at  x20ac 495 million $ 634 million , compared to  x20ac 497 million a year earlier .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9990246295928955,
#    0.0005302104982547462,
#    0.00044515138142742217]},
#  {'sequence': 'Thanks to its extensive industry and operations experience , Cybercom offers strategic and technological expertise to these markets : telecom , industry , media , public sector , retail , and banking and financial services .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9989415407180786,
#    0.0005727228126488626,
#    0.0004857370222453028]},
#  {'sequence': 'Ruukki Romania , the local arm of Finnish metal producer Ruukki , increased its capital by 900,000 euro ( $ 1.14 mln ) through cash contribution , it was reported on September 19 , 2006 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.999049961566925,
#    0.0005340920761227608,
#    0.00041599851101636887]},
#  {'sequence': 'At CapMan Haavisto will be responsible for Group Finances and Accounting and IT .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.999087393283844,
#    0.00046195380855351686,
#    0.0004505865217652172]},
#  {'sequence': 'The EBRD is using its own funds to provide a 21.6 mln A loan while the B portion of 10 mln Euros has been syndicated to two Finnish commercial banks , Nordea Bank Finland Plc 7.7 mln Euros and Pohjola Bank Plc 2.3 mln Euros .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991003274917603,
#    0.0004601036780513823,
#    0.0004395179857965559]},
#  {'sequence': 'Panostaja did not disclose the purchase price .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990867376327515,
#    0.0004605793801601976,
#    0.00045267771929502487]},
#  {'sequence': 'The Internal Revenue Service sees about 20 percent of all taxpayers wait until the last two weeks to file , with about 40 million returns filed in April .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990981817245483,
#    0.0004567471914924681,
#    0.00044511479791253805]},
#  {'sequence': '`` With this agreement , we can continue our good cooperationand at the same time release capital that has been tied up in ourmachinery operation .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990364909172058,
#    0.0005362650263123214,
#    0.0004271931538823992]},
#  {'sequence': 'GS Engineering will install the valves at a liquefied natural gas LNG plant it has built for UAE LNG extraction and gas plants operator GASCO in Ruwais , UAE .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.999023973941803, 0.0005088617326691747, 0.0004672014620155096]},
#  {'sequence': '`` The lowering of prices by us and by our competitors shows that the real estate market has stabilised and returned into balance and apartments are acquiring a fair price in the eyes of our clients .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9987885355949402,
#    0.0007230795454233885,
#    0.0004883401561528444]},
#  {'sequence': 'The companies expect the first orders already in 2011 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.999091386795044,
#    0.0004975103656761348,
#    0.00041105778655037284]},
#  {'sequence': 'Net income from life insurance doubled to EUR 6.8 mn from EUR 3.2 mn , and net income from non-life insurance rose to EUR 5.2 mn from EUR 1.5 mn in the corresponding period in 2009 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990886449813843,
#    0.00048227974912151694,
#    0.00042909386684186757]},
#  {'sequence': 'ALEXANDRIA , Va. , Oct. 6 -- United States Patent no. 7,804,288 , issued on Sept. 28 , was assigned to Vacon Oyj ( Vaasa , Finland ) .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991155862808228,
#    0.0004473343724384904,
#    0.00043710466707125306]},
#  {'sequence': '128,538 shares can still be subscribed for with Series E share options , max .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.999079704284668, 0.0004650224873330444, 0.0004552545433398336]},
#  {'sequence': 'However , he expects banks to provide alternative financing .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990099668502808,
#    0.0005224885535426438,
#    0.0004675413074437529]},
#  {'sequence': 'The chain posted sales of 298 million euros for full 2005 , a rise of 19.5 percent , year-on-year .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990767240524292,
#    0.0005180018488317728,
#    0.00040524458745494485]},
#  {'sequence': "The company 's advantage in pricing can be seen in the significantly lower prices offered by the new unmanned stations .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9989446997642517,
#    0.0005863661644980311,
#    0.00046891297097317874]},
#  {'sequence': 'The company said production volumes so far indicate the circuit is capable of the targeted output rate of 60,000 tonnes per day , or 22 million tonnes a year .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990938901901245,
#    0.00045843474799767137,
#    0.0004477735492400825]},
#  {'sequence': 'The ore body is sufficient to support anticipated production for at least 46 years .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990522861480713,
#    0.0004881705972366035,
#    0.0004594980855472386]},
#  {'sequence': "`` UPM 's deliveries increased during the third quarter by 4 percent , and the efficiency of operations improved , '' Chief Executive Jussi Pesonen said .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9991051554679871,
#    0.00048697669990360737,
#    0.00040787633042782545]},
#  {'sequence': 'Finnish developer and manufacturer of mobile phone chargers Salcomp Plc OMX Helsinki : SAL1V on Wednesday 19 November lowered its full-year net sales estimate .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9990391731262207,
#    0.0005180985317565501,
#    0.00044277679990045726]},
#  {'sequence': "- Counter your competitor 's strengths and target their weaknesses .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990750551223755,
#    0.00047268084017559886,
#    0.0004522563540376723]},
#  {'sequence': 'Profit after taxes for the period was up to EUR0 .9 m , from EUR0 .01 m last year .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990808367729187,
#    0.0004973135655745864,
#    0.00042191281681880355]},
#  {'sequence': 'Deliveries have started and the network will be ready for a launch soon .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990668296813965,
#    0.0005138528067618608,
#    0.00041934807086363435]},
#  {'sequence': '( ADP News ) - Feb 11 , 2009 - Finnish wood products technology supplier Raute Oyj ( HEL : RUTAV ) said today its net profit decreased to EUR 4.7 million ( USD 6.1 m ) for 2008 from EUR 6.6 million for 2007 .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9990301132202148,
#    0.0005254779825918376,
#    0.00044440472265705466]},
#  {'sequence': 'Under the rental agreement , Stockmann was committed to invest in the building of a bridge over the Gogol Street or build an underground tunnel for crossing the street by 2004 .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990498423576355,
#    0.0004846763622481376,
#    0.0004654998774640262]},
#  {'sequence': "Finnish electronics manufacturer PKC Group Oyj ( OMX Helsinki : PKC1V ) said on Wednesday ( 31 December ) that it has completed the acquisition of MAN Nutzfahrzeuge AG 's cable harness business from MAN Star Trucks & Buses Spolka zoo in Poland .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9988586902618408, 0.000677669420838356, 0.0004635521618183702]},
#  {'sequence': "This new deal has strengthened the partnership from Telemig Celular and Tecnomen , which it has started since the beginning of Telemig 's prepaid operations .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990529417991638,
#    0.0005158500280231237,
#    0.00043129068217240274]},
#  {'sequence': 'The company has 120 employees and annual sales of approximately EUR16m .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990931749343872,
#    0.00045596269774250686,
#    0.00045075025991536677]},
#  {'sequence': "`` After a long , unprofitable period the Food Division posted a profitable result , which speaks of a healthier cost structure and a new approach in business operations , '' Rihko said .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.999056875705719,
#    0.0005214542034082115,
#    0.00042162160389125347]},
#  {'sequence': "An audio webcast will be available live and archived on Cerner 's Web site at www.cerner.com .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991130232810974,
#    0.0004467667022254318,
#    0.0004401664191391319]},
#  {'sequence': 'Earnings per share ( EPS ) for the first quarter 2007 amounted to EUR0 .07 , up from EUR0 .04 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990828633308411,
#    0.0004926009569317102,
#    0.00042451327317394316]},
#  {'sequence': 'Finnish beverage company Olvi is one of the last listed companies in Finland that has not yet published its financial result for the second quarter of 2009 .',
#   'labels': ['neutral', 'negative', 'positive'],
#   'scores': [0.9991151094436646,
#    0.0004456732131075114,
#    0.0004392210394144058]},
#  {'sequence': "Lassila & Tikanoja 's operating profit excluding non-recurring and imputed items for the second quarter was EUR11 .3 m , down from EUR13 .8 m a year ago .",
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9990246295928955,
#    0.0005175702972337604,
#    0.0004577365762088448]},
#  {'sequence': "Jun. 14 , 2009 ( AOL Weblogs delivered by Newstex ) -- Looks like the E71 is about to be upstaged as Nokia 's ( NYSE : NOK ) premier business-class smartphone -- someone in Espoo 's just hit the corporate YouTube account with this promo video for an E72 .",
#   'labels': ['neutral', 'negative', 'positive'],
#   'scores': [0.9926893711090088, 0.00677220243960619, 0.000538413820322603]},
#  {'sequence': 'Finnish Ahlstrom Corporation has ordered key production equipment for a new glass nonwovens production line at its Russian Tver Mill from Finnish Vaahto Pulp & Paper Machinery ( that is part of Vaahto Group ) .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9989991784095764,
#    0.000556928338482976,
#    0.00044397098827175796]},
#  {'sequence': 'The business transfer will take effect from 1 January 2007 , and in connection with this 47 employees will transfer from Elisa to Daxtum as continuing employees .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991017580032349,
#    0.0004521730588749051,
#    0.0004461031057871878]},
#  {'sequence': 'Janno Reiljan , a member of the Eesti Energia supervisory board , said the owners of Narva Power Grid had informed Eesti Energia about their wish to sell .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990987181663513,
#    0.0004625928704626858,
#    0.00043869714136235416]},
#  {'sequence': 'Both operating profit and turnover for the three-month period increased , respectively from EUR0 .9 m and EUR8 .3 m , as compared to the corresponding period in 2005 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990826845169067,
#    0.0004998369258828461,
#    0.00041753501864150167]},
#  {'sequence': 'Operating profit decreased to EUR 16mn from EUR 21.1 mn in 2008 .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9990536570549011,
#    0.0004946736735291779,
#    0.00045173760736361146]},
#  {'sequence': 'A new Kveyt light variety of Suomalainen Pekoni marketed under the Atria brand name is now available to consumers in Finland .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9988541603088379,
#    0.0006874806131236255,
#    0.00045826658606529236]},
#  {'sequence': 'Sales at the Tiimari business went down by 8 % to EUR 11.8 million , while Gallerix stores saw 29 % growth to EUR 2 million .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.642306923866272, 0.18340234458446503, 0.17429067194461823]},
#  {'sequence': 'Aspocomp intends to set up a plant to manufacture printed circuit boards with an investment of Rs310 crore .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.999082088470459, 0.0004731750232167542, 0.0004447631654329598]},
#  {'sequence': 'The StoneGate product family was designed to provide the full benefits of a unified management system including shared logging , reporting and auditing .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9986781477928162,
#    0.0008266944205388427,
#    0.0004951574956066906]},
#  {'sequence': '`` We are pleased to welcome Tapeks Noma into Cramo group .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9974556565284729,
#    0.0020004769321531057,
#    0.0005438871448859572]},
#  {'sequence': 'Changes to the as-built models from the design were communicated to the subcontractors to accommodate them into the steel and GRC fabrication process .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990924596786499,
#    0.0004579613741952926,
#    0.00044960613013245165]},
#  {'sequence': "Viking Line 's cargo revenue increased by 5.4 % to EUR 21.46 mn , and cargo volume increased by 2.4 % to 70,116 cargo units .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9991053938865662,
#    0.00048700274783186615,
#    0.0004076089826412499]},
#  {'sequence': 'The transaction is subject to a final agreement between the parties , approvals of their decision-making bodies and approval by the Finnish Competition Authority .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9989578723907471,
#    0.0005396759952418506,
#    0.0005024172132834792]},
#  {'sequence': 'The EBRD is using its own funds to provide a 21.6 million A loan while the B portion of 10 million Euros has been syndicated to two Finnish commercial banks , Nordea Bank Finland Plc and Pohjola Bank Plc. .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990878701210022, 0.0004671555361710489, 0.000444942299509421]},
#  {'sequence': 'Digia said its consolidated net sales for January-June 2010 were EUR67 .8 m , up 9.7 % on the same period in 2009 ( EUR61 .9 m ) .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990613460540771,
#    0.0005190218216739595,
#    0.0004196667287033051]},
#  {'sequence': 'The value of the order is EUR 700,000 .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991083741188049,
#    0.00044635956874117255,
#    0.0004453091532923281]},
#  {'sequence': 'Finnish security and privacy software solutions developer Stonesoft Oyj said on January 7 , 2008 that the preliminary sales of its StoneGate products grew by 59 pct year-on-year to 3.6 mln euro ( $ 5.3 mln ) for the fourth quarter of 2007 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9991064071655273,
#    0.0004882955690845847,
#    0.0004052518052048981]},
#  {'sequence': 'The value of the order is nearly EUR400m .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991066455841064,
#    0.0004483909870032221,
#    0.0004449542611837387]},
#  {'sequence': "STOCKMANN plc COMPANY ANNOUNCEMENT February 20 , 2007 , at 13.40 An annual summary of Stockmann 's stock exchange and financial press releases in 2006 is available on the company 's website at the address www.stockmann.com .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991430640220642,
#    0.00042903664871118963,
#    0.0004278132691979408]},
#  {'sequence': '( ADP News ) - Feb 11 , 2009 - Finnish management software solutions provider Ixonos Oyj ( HEL : XNS1V ) said today its net profit rose to EUR 3.5 million ( USD 4.5 m ) for 2008 from EUR 3.1 million for 2007 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990922212600708,
#    0.0004909298731945455,
#    0.00041683446033857763]},
#  {'sequence': "` It is a testament to the quality of our LTE solution and our commitment to the Japanese market ' , he added .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9989469051361084,
#    0.0005379542708396912,
#    0.0005151958903297782]},
#  {'sequence': "Nokia - the world 's largest mobile phone manufacturer - and China Postel - China 's largest mobile phone distributor - have a long-standing partnership that continues to grow stronger over time .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990954399108887,
#    0.0004942743107676506,
#    0.0004102895618416369]},
#  {'sequence': "Finnish forest machinery manufacturer Ponsse 's net sales grew to EUR 51.3 mn in the first quarter of 2010 from EUR 37.5 mn in the corresponding period in 2009 .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990779757499695,
#    0.0004858544853050262,
#    0.00043619057396426797]},
#  {'sequence': 'The contract is worth some EUR 1 million .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990901350975037,
#    0.00046168421977199614,
#    0.0004481517244130373]},
#  {'sequence': 'In 2010 , the Marimekko Group s net sales were EUR 73,297 thousand ( EUR 72,473 thousand ) and operating profit was EUR 8,169 thousand ( EUR 6,291 thousand ) .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991170763969421,
#    0.000444551813416183,
#    0.00043839719728566706]},
#  {'sequence': 'Curators have divided their material into eight themes .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990700483322144,
#    0.00046952429693192244,
#    0.0004604121495503932]},
#  {'sequence': 'PGE Belchatow runs the 4.44 GW Belchatow coal-fired power plant , and Fortum has intentions to start a CCS demonstration project jointly with Teollisuuden Voima Oyj ( TVO ) - another Finnish utility - at the their jointly owned 565MW Meri-Pori coal-fired facility .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990391731262207,
#    0.0004970787558704615,
#    0.0004637724196072668]},
#  {'sequence': 'Operating loss totalled EUR 12.7 mn , compared to a profit of EUR 17.7 mn in the first half of 2008 .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9990063309669495,
#    0.0005592682864516973,
#    0.0004344265616964549]},
#  {'sequence': "17 March 2011 - Goldman Sachs estimates that there are negative prospects for the Norwegian mobile operations of Norway 's Telenor ASA OSL : TEL and Sweden 's TeliaSonera AB STO : TLSN in the short term .",
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9990423917770386,
#    0.0005185712361708283,
#    0.0004390929243527353]},
#  {'sequence': "Liora 's got a brand-new bag .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990551471710205,
#    0.0004802633193321526,
#    0.00046462181489914656]},
#  {'sequence': 'The Filter Tips cover the volume range from 0.1-1200 -ðl including new sizes for 10 , 20 , 100-120 , 200 , 300 , 1000 and 1200 -ðl volume capacities .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991348385810852,
#    0.0004376272263471037,
#    0.00042753771413117647]},
#  {'sequence': "In Finland , OP-Pohjola 's staff union is boycotting the group 's insurance sales tasks because the company has refused to take the sale of insurance into account in determining wages .",
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9990546107292175,
#    0.000508190190885216,
#    0.00043722029658965766]},
#  {'sequence': "Following the divestment , Fiskars 's Outdoor unit will comprise the brands Gerber , Silva and Buster , and will focus on multi-tools , knives , compasses , mobile lighting , pedometers , and aluminium boats .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990838170051575, 0.000468211539555341, 0.0004480447096284479]},
#  {'sequence': 'Atria Group is a leading Scandinavian meat products group .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.998590886592865, 0.0009496925049461424, 0.0004594336496666074]},
#  {'sequence': 'The sale , comprising the margarine business in Finland and Poland , follows the approval of the Polish competition authorities earlier in October .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991052746772766,
#    0.00045190576929599047,
#    0.0004427798849064857]},
#  {'sequence': 'In January-June 2010 , diluted loss per share stood at EUR0 .3 versus EUR0 .1 in the first half of 2009 .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.999053418636322, 0.0005051016923971474, 0.0004414559225551784]},
#  {'sequence': 'Sami Sepp+Ænen , CEO for Elisa Eesti , says the novel network allows fast mobile broadband for sparsely populated areas .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990893006324768,
#    0.00046720431419089437,
#    0.0004434955189935863]},
#  {'sequence': 'It operates under three distinct brands : United Supermarkets , Market Street and United Supermercado .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990845322608948,
#    0.0004657040408346802,
#    0.00044968901784159243]},
#  {'sequence': "POYRY PLCCompany Announcement 10 December 2010 at 4.10 p.m. Pursuant to Poyry PLC 's stock option program 2004 , 63 792 new shares of the company have been subscribed since 27 October 2010 with stock options 2004B .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.999132513999939, 0.000438179646153003, 0.00042926889727823436]},
#  {'sequence': 'Ruukki is restructuring commercial and industrial construction operations in pursuit of permanent improvements whilst adjusting operations to market conditions .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990851283073425,
#    0.0004662995634134859,
#    0.00044863438233733177]},
#  {'sequence': 'The shops are located in the capital region and the Paijat-Hame region .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990445971488953,
#    0.00048735542804934084,
#    0.00046800580457784235]},
#  {'sequence': "The presentation material can be viewed on the company 's website in English after the conference .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.999082088470459, 0.0004636065277736634, 0.0004543242685031146]},
#  {'sequence': 'Additionally , the company will use the solutions to automate the preparation of financial statements according to IFRS standard .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990649223327637,
#    0.0004835810395888984,
#    0.0004515318141784519]},
#  {'sequence': "`` The acquisition of Elektros Pavara completes KONE 's market expansion strategy in the Baltic Countries .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9986898899078369,
#    0.0008434202172793448,
#    0.0004668011097237468]},
#  {'sequence': 'The company expects to open its first online shop in the US in the summer in 2011 .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9973825812339783, 0.0021415017545223236, 0.000475877255667001]},
#  {'sequence': "The company 's profit totaled Ls 578,100 in H1 2007 , down 30.9 % year-on-year .",
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9990582466125488,
#    0.0004963799729011953,
#    0.0004454031295608729]},
#  {'sequence': 'TELECOMWORLDWIRE-7 April 2006-TJ Group Plc sells stake in Morning Digital Design Oy Finnish IT company TJ Group Plc said on Friday 7 April that it had signed an agreement on selling its shares of Morning Digital Design Oy to Edita Oyj .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9983024597167969,
#    0.0011440991656854749,
#    0.0005534632946364582]},
#  {'sequence': "Nokian Capacitors ' equipment will be used to raise the capacity and reliability of the Indian grid .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.999026358127594,
#    0.0005466672009788454,
#    0.00042699111509136856]},
#  {'sequence': "`` EB Tough VoIP was designed to fulfill the communications needs of military units , and we continue to strive towards achieving that goal , '' Mikko Viitaniemi , EB Elektrobit Defense Products , Wireless Solutions senior manager , said in a statement .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9989956021308899,
#    0.0005440058885142207,
#    0.00046042504254728556]},
#  {'sequence': 'The German company has also signed a code share agreement with another Oneworld member -- American Airlines Inc , part of US-based AMR Corp ( NYSE : AMR ) .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9989568591117859,
#    0.0005895077483728528,
#    0.00045362109085544944]},
#  {'sequence': 'Finnish fibers and plastic products maker Suominen Corporation said its net loss narrowed to 1.6 mln euro $ 2.0 mln in the first nine months of 2006 from 2.16 mln euro $ 2.7 mln in the same period of 2005 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9989568591117859,
#    0.0005576416151598096,
#    0.0004854257858823985]},
#  {'sequence': "Olvi 's target is to strengthen its market share in soft drinks , mineral waters , ciders , long drinks , and energy drinks .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9989762902259827,
#    0.0005323667428456247,
#    0.0004912899457849562]},
#  {'sequence': "Danske Bank is Denmark 's largest bank with 3.5 million customers .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990438222885132,
#    0.0004927458940073848,
#    0.00046341444249264896]},
#  {'sequence': 'EQT has completed its exit from Salcomp , a Finnish company that makes mobile phone chargers , by selling its remaining stake to Swedish investment group Nordstjernan for about ( EURO ) 35 million ( $ 47 million ) .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990883469581604,
#    0.0004660890845116228,
#    0.00044553607585839927]},
#  {'sequence': "Both Mr Walden and Mr Ignatius will be responsible also for the newspapers ' business result .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990767240524292,
#    0.0004672670620493591,
#    0.0004560095549095422]},
#  {'sequence': "TN means that the handset supports TeliaSonera 's Telia Navigator global positioning system service .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9939119815826416, 0.005323442164808512, 0.0007645296864211559]},
#  {'sequence': "According to Finnish financial services group Sampo 's CEO , Bj+¦rn Wahlroos , Danish Danske Bank 's acquisition of Sampo Bank for EUR 4bn was the largest cash deal in Finland 's economic history .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990864396095276,
#    0.000467791804112494,
#    0.00044577624066732824]},
#  {'sequence': "`` I 'm happy with the outcome , '' Sneed said after the hearing .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990751147270203,
#    0.0005003600963391364,
#    0.00042450454202480614]},
#  {'sequence': 'However , the growth margin slowed down due to the financial crisis .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9990769028663635,
#    0.0004899431369267404,
#    0.00043315335642546415]},
#  {'sequence': 'Vacon aims to establish its presence in the solar energy business in various parts of the world towards the end of 2010 , said Olli Teva , marketing director renewable energy applications .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990726113319397,
#    0.0004789626400452107,
#    0.00044833263382315636]},
#  {'sequence': "`` BasWare 's product sales grew strongly in the financial period , by 24 percent .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990890622138977,
#    0.0005002697580493987,
#    0.0004106090636923909]},
#  {'sequence': 'Secure your files online Like filling out a tax return , making a backup is boring .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990643262863159, 0.000472298008389771, 0.0004633931675925851]},
#  {'sequence': "Frost sold shares for $ 19 million at $ 6.06-7 .12 per share , compared with Friday 's high of $ 11.33 and low of $ 10.14 .",
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9986140131950378,
#    0.0009227533591911197,
#    0.00046316106454469264]},
#  {'sequence': 'The six breweries recorded a 5.2 percent growth in domestic beer sales last year to 270.21 million liters , from 256.88 million liters sold in 2005 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990944266319275,
#    0.0004885160597041249,
#    0.00041697302367538214]},
#  {'sequence': 'Finnair expands : Finnair plans to add more flights on routes to Hong Kong , India and Russia .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.999017596244812,
#    0.0005540785496123135,
#    0.00042834909982047975]},
#  {'sequence': 'The output of the contracts totals 72 MWe .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990995526313782,
#    0.00045159735600464046,
#    0.0004488251870498061]},
#  {'sequence': 'Tiimari , the Finnish retailer , reported to have geenrated quarterly revenues totalling EUR 1.3 mn in the 4th quarter 2009 , up from EUR 0.3 mn loss in 2008 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990754127502441,
#    0.0004960268852300942,
#    0.00042856912477873266]},
#  {'sequence': 'The prices of stainless steel also rose in Europe .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990198612213135,
#    0.0005091080674901605,
#    0.00047109785373322666]},
#  {'sequence': 'KESKO CORPORATION STOCK EXCHANGE RELEASE 28.02.2008 AT 09.30 1 ( 1 ) Kesko Corporation and Aspo plc today signed an agreement by which Aspo acquires the share capital of Kauko-Telko Ltd , a subsidiary wholly owned by Kesko .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990009665489197,
#    0.0005454916972666979,
#    0.0004534930340014398]},
#  {'sequence': 'The period-end cash and cash equivalents totaled EUR6 .5 m , compared to EUR10 .5 m in the previous year .',
#   'labels': ['negative', 'positive', 'neutral'],
#   'scores': [0.6771416664123535, 0.1645525097846985, 0.1583058387041092]},
#  {'sequence': 'However short-term rentals are becoming more popular .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990362524986267,
#    0.0004891625139862299,
#    0.0004745435144286603]},
#  {'sequence': 'Pharmaceutical market in Belgium Global Research & Data Services published recently a market analysis about the pharmaceutical markets in Belgium .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991288185119629,
#    0.00043761375127360225,
#    0.0004335705889388919]},
#  {'sequence': 'Based on the 2005 calendar year the combined company had EUR15 .8 bn in pro forma annual revenues and is expected to start operations with 60,000 employees .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991130232810974,
#    0.00045187596697360277,
#    0.0004351703973952681]},
#  {'sequence': 'The money will be spread mainly over 2011 and 2012 , the company said .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990769028663635,
#    0.0004654236836358905,
#    0.0004577309009619057]},
#  {'sequence': 'The lay-offs will affect 240 people out of the total 320 Okmetic employees in Finland .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9990562200546265,
#    0.0005080101545900106,
#    0.00043578181066550314]},
#  {'sequence': 'In January-September 2007 , operating profit totaled EUR 20.5 mn .',
#   'labels': ['neutral', 'negative', 'positive'],
#   'scores': [0.9990984201431274,
#    0.00045200291788205504,
#    0.00044957909267395735]},
#  {'sequence': 'The annual Thesis contest is aimed to enhance the thesis quality and to strengthen the thesis culture in polytechnics .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.999009370803833,
#    0.0005613798857666552,
#    0.00042929479968734086]},
#  {'sequence': "Finnish Cargotec 's Kalmar has received a significant order from the US Department of Defense .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990856051445007,
#    0.0005001497338525951,
#    0.0004142601101193577]},
#  {'sequence': 'Water Treatment Products In Australia Today , Global Research & Data Services is going to publish a market analysis about the market for chemical water treatment products in Australia .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991387128829956,
#    0.00043395094689913094,
#    0.00042727490654215217]},
#  {'sequence': 'Construction is expected to be completed in the summer of 2011 .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990701675415039,
#    0.00047392171109095216,
#    0.00045589706860482693]},
#  {'sequence': "Den Bosch-based TomTom is Europe 's largest maker of automotive navigation devices , while Cayman Islands-based Garmin is larger in the U.S. and overall .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9989873170852661,
#    0.0005278657772578299,
#    0.00048489755135960877]},
#  {'sequence': 'According to the Latvian business register , Uponor Latvia closed in red with LVL 99,000 EUR 139,538.17 USD 194,556.48 on turnover of LVL 2.346 mn for 2009 .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9990537762641907,
#    0.0005122098373249173,
#    0.0004340028390288353]},
#  {'sequence': 'By acquiring RCP , we can combine our strong knowhow with the expertise of a solid local company .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.999035656452179,
#    0.0005368739948607981,
#    0.00042749085696414113]},
#  {'sequence': 'Finnish business software group AffectoGenimap Oyj said it had signed an agreement to acquire all the shares in Swedish sector company Intellibis Ab for 12 mln euro ( $ 15.8 mln ) on a debt-free basis .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990300536155701,
#    0.0005387077108025551,
#    0.00043118311441503465]},
#  {'sequence': 'TeliaSonera has secured deliveries for 4G modems with support for 3G and 2G during the second quarter 2010 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990639686584473,
#    0.0005123291630297899,
#    0.0004237191460561007]},
#  {'sequence': 'Finnish glass technology group Glaston Corporation ( OMX Helsinki : GLA1V ) reported on Thursday ( 14 August ) an operating profit of EUR6 .5 m on net sales of EUR201 .5 m for the period January-September 2008 .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991303086280823,
#    0.00043869554065167904,
#    0.00043107924284413457]},
#  {'sequence': "The airline 's share price closed down slightly at (  x20ac ) 12.51 ( $ 15US .74 ) in Helsinki .",
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9990348815917969,
#    0.0005287611274980009,
#    0.00043636030750349164]},
#  {'sequence': "We are very excited working with Maxis on this first commercial deployment of ` Master of Maya ' , said Joe Doering , Head of the Asia South region at Nokia Siemens Networks .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990559220314026,
#    0.0005183368921279907,
#    0.0004257784748915583]},
#  {'sequence': 'Pharmaceuticals - Netherlands This brand-new market analysis gives a clear overview of the actual situation and future outlook of the pharmaceutical market in Netherlands .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991424679756165,
#    0.00042916976963169873,
#    0.00042837110231630504]},
#  {'sequence': "Elcoteq 's revenues in 2007 were approximately EUR 120 million .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991070032119751,
#    0.0004490688443183899,
#    0.0004439233453013003]},
#  {'sequence': 'In Q2 of 2009 , profit before taxes amounted to EUR 13.6 mn , down from EUR 26.8 mn in Q2 of 2008 .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9990500807762146,
#    0.0005049289320595562,
#    0.0004450410488061607]},
#  {'sequence': 'Founded in 1946 , Strand Associates , which provides civil , environmental , transportation , electrical and mechanical engineering services , has 350 employees at 10 offices in Wisconsin , Alabama , Illinois , Indiana , Kentucky and Ohio .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991176128387451,
#    0.00045001631951890886,
#    0.00043233277392573655]},
#  {'sequence': "South African Sappi will become the largest foreign forest industry company operating in Finland as a result of the acquisition Finnish M-real Corporation 's Graphic Papers Business unit .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990126490592957,
#    0.0005440790555439889,
#    0.0004432997084222734]},
#  {'sequence': 'According to Finnish pension insurance company Varma , Varma was the recipient of over two thirds of the revenue of the earnings-related pension cover that was under competitive tendering in Finland .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990975260734558,
#    0.00045984634198248386,
#    0.00044260919094085693]},
#  {'sequence': 'Particular attention is being paid to energy efficiency in the construction of the building , as it is designed to meet the requirements of energy class B , and LEED certification will be applied for .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9989676475524902,
#    0.0005309445550665259,
#    0.0005014160997234285]},
#  {'sequence': 'Raute Corporation has received orders worth over EUR 12 million from OOO Ilim Bratsk DOK in Russia .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990560412406921, 0.0005254972493276, 0.0004184841236565262]},
#  {'sequence': 'Private equity investor CapMan , the owner of Finnish Lumene cosmetics company , is planning to list Lumene .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990897178649902,
#    0.00046302026021294296,
#    0.00044727601925842464]},
#  {'sequence': 'It estimates the operating profit to further improve from the third quarter .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990871548652649,
#    0.0005007083527743816,
#    0.00041204315493814647]},
# ...
#   'scores': [0.9988730549812317,
#    0.0006185388192534447,
#    0.0005083927535451949]},
#  {'sequence': 'Jussi Pesonen , member of the Sampo Board since 2006 , will renounce his seat in Sampo Board .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990890622138977,
#    0.0004579719970934093,
#    0.0004528950958047062]},
#  {'sequence': "The subscriptions increase Cargotec 's share capital by EUR 27,060 .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.999042272567749,
#    0.0005270332330837846,
#    0.00043066206853836775]},
#  {'sequence': 'No financial details were revealed .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990730285644531,
#    0.0004670013440772891,
#    0.00045997879351489246]},
#  {'sequence': 'Master of Mayawas jointly developed by Nokia Siemens Networks and UFA - FremantleMedia , and will be actively advertised by Maxis in the end of May 2007 .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990743398666382,
#    0.00047424202784895897,
#    0.000451452360721305]},
#  {'sequence': 'Asian traffic declined by 3.4 per cent .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9990665912628174,
#    0.0004896614700555801,
#    0.0004436995950527489]},
#  {'sequence': 'Analysts surveyed by Thomson Financial expected revenue of $ 69 million for the quarter .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990807175636292,
#    0.0004642434068955481,
#    0.00045502150896936655]},
#  {'sequence': "The economic occupancy rate of Sponda 's property portfolio rose to 91.2 % from 88.8 % in 2006 .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990877509117126,
#    0.0004858853353653103,
#    0.00042639882303774357]},
#  {'sequence': "It delivers a different user experience and enables us to widen the market we can address . ''",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.99871426820755, 0.0008380564977414906, 0.0004476424364838749]},
#  {'sequence': 'Componenta will also offer a five-year subordinated loan for subscription by the public .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990718364715576,
#    0.0004735011316370219,
#    0.00045462511479854584]},
#  {'sequence': 'Diluted EPS rose to EUR3 .68 from EUR0 .50 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990682601928711,
#    0.0005070420447736979,
#    0.00042465399019420147]},
#  {'sequence': 'HELSINKI ( AFX ) - Retail and wholesale group Kesko reported net sales of 659.4 mln eur for February , an increase of 10.8 pct year-on-year .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990784525871277,
#    0.0005117200780659914,
#    0.0004098047793377191]},
#  {'sequence': 'Vacon controls a further 5 % of the company via investment fund Power Fund I. EUR 1.0 = USD 1.397',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990971684455872,
#    0.0004556658095680177,
#    0.0004471364081837237]},
#  {'sequence': 'Finnish energy company Fortum has set itself new stricter target limits for short-term carbon dioxide emissions from its heat and electricity production .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990848302841187,
#    0.0004707816115114838,
#    0.0004444267542567104]},
#  {'sequence': 'Our customers come from the following countries : UK , USA , Spain , France , Italy , Germany , China , Sweden , Norway , Netherlands , Austria , Belgium , Switzerland , Czech Republic , Serbia , Finland , Canada , Russia , Ukraine , Portugal , Denmark , Ireland , South Korea , Estonia and Liechtenstein .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990888833999634,
#    0.0004664519219659269,
#    0.0004445974191185087]},
#  {'sequence': 'The value of the orders is about EUR 70mn .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991062879562378,
#    0.00044887803960591555,
#    0.00044486302067525685]},
#  {'sequence': 'Patrick Jeambar will also continue being responsible for Innovation and Health , safety and environment HSEA functions of Ahlstrom Corporation .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990723133087158,
#    0.00047443987568840384,
#    0.000453292770544067]},
#  {'sequence': 'The new B shares carry the right to dividend and other shareholder rights with effect from today .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990957975387573,
#    0.0004531063896138221,
#    0.0004510917351581156]},
#  {'sequence': "This new representation extends Comptel 's global presence to a total of 18 countries , serving over 250 customers in over 80 countries worldwide .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9989852905273438,
#    0.0005666616489179432,
#    0.0004480155184864998]},
#  {'sequence': 'The name of the newspaper publishing and printing division Sanoma will be changed to Sanoma News .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990803003311157, 0.000466007535578683, 0.0004536662017926574]},
#  {'sequence': 'The fourth quarter saw Rapala swing back to a pretax profit of 1.5 mln eur from a year earlier loss of 1.2 mln on the back of a 30 pct uplift in sales to 44.8 mln eur , and a stronger performance in North America .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990927577018738,
#    0.0005032499902881682,
#    0.0004039800551254302]},
#  {'sequence': "Another noticeable thing is that the search for Tata and Airtel brands was mostly related to ` broadband connections ' .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990760087966919,
#    0.0004682214930653572,
#    0.0004557732318062335]},
#  {'sequence': 'Both operating profit and net sales for the six-month period increased , respectively from EUR18 .1 m and EUR127 .6 m , as compared to the corresponding period in 2006 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.99908846616745, 0.0004978729411959648, 0.000413617497542873]},
#  {'sequence': 'Currently the quarterly applied surcharges differ significantly from the actual market prices .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990901350975037,
#    0.00045766416587866843,
#    0.000452092761406675]},
#  {'sequence': 'The company said Offshore segment represented 43 % of the total marine engines orders for the July-September 2010 period , Merchant 33 % , Special vessels 18 % , and Cruise and Ferry , and Ship Design -- 2 % and 3 % , respectively .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990935921669006,
#    0.0004636929661501199,
#    0.0004426801751833409]},
#  {'sequence': "The Finnish paints company acquired the remaining 49 pct that it did not own from Ukraine 's LGU for an undisclosed sum .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990648627281189,
#    0.00047226418973878026,
#    0.0004628566384781152]},
#  {'sequence': 'The purchase price was not disclosed .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990657567977905,
#    0.00047007756074890494,
#    0.00046416959958150983]},
#  {'sequence': "Furthermore , efficiency improvement measures initiated earlier are now bearing fruit , '' CEO Jan Lang said .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.999083936214447,
#    0.0005057310918346047,
#    0.00041036243783310056]},
#  {'sequence': 'The value of the deal has not been disclosed .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990881681442261,
#    0.00045925393351353705,
#    0.0004525636322796345]},
#  {'sequence': "Moreover , Konecranes and Kito intend to transfer the hoist distribution business of Konecranes ' Japanese joint venture MHS Konecranes to Kito .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990654587745667,
#    0.00047643043217249215,
#    0.00045811565360054374]},
#  {'sequence': '( I&H ) in a move to enhance growth .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9989936947822571,
#    0.0005680910544469953,
#    0.0004382914339657873]},
#  {'sequence': 'Operating loss totalled EUR 3.2 mn , compared to a profit of EUR 7.2 mn in the third quarter of 2008 .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9989956617355347,
#    0.0005668556550517678,
#    0.0004374715790618211]},
#  {'sequence': 'The contract traded at an all-time high of $ 50,200 a ton on April 24 .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990826845169067,
#    0.0004641603445634246,
#    0.0004532141610980034]},
#  {'sequence': 'In addition , Kone signed a two-year maintenance contract for the escalators .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990599751472473,
#    0.0005152557278051972,
#    0.0004247227043379098]},
#  {'sequence': 'One can also apply for jobs directly from the iPad , select which CV to attach and which covering letter is most appropriate for each position .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.999109148979187,
#    0.00045249168761074543,
#    0.0004382700426504016]},
#  {'sequence': 'The combination of all services enabling us to offer a complex and strengthened service chain not only limited to the Baltic port connections but also for getting access to the world wide Grimaldi Network into the Mediterranean , Africa and North America `` says Uwe Bakosch .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990163445472717,
#    0.0005635624984279275,
#    0.00042012956691905856]},
#  {'sequence': 'Union and company officials did not return calls yesterday .',
#   'labels': ['neutral', 'negative', 'positive'],
#   'scores': [0.9990951418876648,
#    0.00045388491707853973,
#    0.00045100803254172206]},
#  {'sequence': 'Turun kaupunkin , Finland based company has awarded contract to Lemminkainen Talotekniikka Oy for electrical installation work .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990741610527039, 0.000497700588312, 0.00042818067595362663]},
#  {'sequence': 'ALEXANDRIA , Va. , Nov. 19 -- Erkki Aho , Elimaki , Finland , has developed a method and apparatus in conjunction with a shoe press .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.999106228351593,
#    0.00045415974454954267,
#    0.0004396421427372843]},
#  {'sequence': 'ADPnews - Jul 17 , 2009 - Finland-based steel maker Rautaruukki Oyj Ruukki HEL : RTRKS said today it slipped to a net loss of EUR 184 million USD 259.7 m for the first half of 2009 from a net profit of EUR 2',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9990544319152832,
#    0.0005114387604407966,
#    0.00043412254308350384]},
#  {'sequence': "In addition , the Kazakh delegation will visit Finland 's SITRA investment fund , Honkarakenne Ltd and Nokia headquarters to study TeliaSonera Ltd JSC 's activities .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990958571434021,
#    0.00046043575275689363,
#    0.0004437544848769903]},
#  {'sequence': 'Rapala VMC Corporation ( Rapala ) is a Finland-based company engaged in the manufacture and distribution of fishing equipment and accessories .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990912079811096,
#    0.00046246033161878586,
#    0.0004463380901142955]},
#  {'sequence': 'Lean System supports change management and component purchasing extremely well .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990069270133972,
#    0.0005483488203026354,
#    0.0004446614475455135]},
#  {'sequence': 'Yvonne Jones is owner of Chameleon Interiors .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990912675857544,
#    0.00045818876242265105,
#    0.00045051606139168143]},
#  {'sequence': 'Sales rose 10 pct to 566 mln eur on the back of strong volume and favourable currency effects .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990795254707336,
#    0.0005110735073685646,
#    0.0004093733732588589]},
#  {'sequence': 'According to Ultrascan , with a software acquired from crackers , it has managed to change the mobile phone in a way that the phone was able to get hold of a one-time password sent by a bank via a text message .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991070032119751,
#    0.00045098704867996275,
#    0.000442064949311316]},
#  {'sequence': 'However , two of the previously ordered sets will start producing electricity at the end of October 2010 , it said .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990267157554626,
#    0.0005041013355366886,
#    0.0004691672802437097]},
#  {'sequence': 'A realignment of interests in the sector is clearly under way .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990710616111755,
#    0.0005157089326530695,
#    0.0004131972964387387]},
#  {'sequence': 'Therefore , Phase III of the research will not be conducted by Abbott .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990494251251221,
#    0.0004783428448718041,
#    0.00047220950364135206]},
#  {'sequence': 'Profit before taxes amounted to EUR 56.5 mn , down from EUR 232.9 mn a year ago .',
#   'labels': ['negative', 'neutral', 'positive'],
#   'scores': [0.9990374445915222,
#    0.0005222883191891015,
#    0.00044028914999216795]},
#  {'sequence': 'Citigroup , Inc ( NYSE : C ) has announced that its Global Transaction Services ( GTS ) business has been awarded a new mandate by Finland-based Pohjola Bank Group .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990937113761902, 0.0004980379599146545, 0.000408221036195755]},
#  {'sequence': "Investors will continue being interested in the company 's share although it is not quite cheap , Affarsvarlden said .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9988813400268555,
#    0.0006036023260094225,
#    0.0005150986835360527]},
#  {'sequence': 'No more waste-burning facilities should be built .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990410804748535,
#    0.0004858946776948869,
#    0.00047297976561821997]},
#  {'sequence': "Last month , Outokumpu sold more than 80 percent of its technology unit , Outokumpu Technology Oyj , to further its strategic goal of becoming the world 's largest stainless steel maker .",
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990705251693726,
#    0.0005085700540803373,
#    0.0004209575999993831]},
#  {'sequence': 'The actions are expected to deliver annual cost savings of some EUR15-20m .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.99906325340271, 0.0005150152719579637, 0.00042177061550319195]},
#  {'sequence': '( ADPnews ) - Dec 30 , 2009 - Finnish investment group Neomarkka Oyj ( HEL : NEMBV ) said today that it will furlough employee in its unit Reka Cables Ltd for less than 90 days , starting in January 2010 .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9991102814674377, 0.0004530400619842112, 0.000436698755947873]},
#  {'sequence': 'The company said that the results of the third quarter do not include non-recurring items .',
#   'labels': ['neutral', 'negative', 'positive'],
#   'scores': [0.99909907579422, 0.00045130657963454723, 0.0004496781330090016]},
#  {'sequence': "The equipment will be made at Vaahto 's plant in Hollola in Finland , and delivery is scheduled for the first quarter of 2009 .",
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990665912628174,
#    0.0004758911964017898,
#    0.00045757091720588505]},
#  {'sequence': 'A broad range of connectivity options including 3G - HSPA and Wi-Fi gives consumers high speed access to the Internet .',
#   'labels': ['neutral', 'positive', 'negative'],
#   'scores': [0.9990882277488708,
#    0.0004640267288777977,
#    0.00044774336856789887]},
#  {'sequence': 'Diluted earnings per share ( EPS ) rose to EUR 0.29 from EUR 0.05 .',
#   'labels': ['positive', 'neutral', 'negative'],
#   'scores': [0.9990966320037842,
#    0.0004783833574037999,
#    0.00042497532558627427]}]

# %%
# Extracting sentiments
y_pred = [i['labels'][0] for i in y_pred]
y_pred
# Out:
# ['neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'negative',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'negative',
#  'negative',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'positive',
#  'neutral',
#  'negative',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'negative',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'negative',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'negative',
#  'neutral',
#  'neutral',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'neutral',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'neutral',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'negative',
#  'negative',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'negative',
#  'neutral',
#  'negative',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'negative',
#  'neutral',
#  'negative',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'positive',
#  'negative',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'negative',
#  'neutral',
#  'neutral',
#  'negative',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'neutral',
#  'positive',
#  'negative',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'neutral',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'negative',
#  'neutral',
#  'neutral',
#  'negative',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'neutral',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'negative',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'negative',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive']

# %%
# Trained model performance
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.95      0.97      0.96       118
#      neutral       0.99      0.99      0.99       563
#     positive       0.98      0.98      0.98       287
#
#     accuracy                           0.98       968
#    macro avg       0.97      0.98      0.97       968
# weighted avg       0.98      0.98      0.98       968

# %% [markdown]
# # Observations:
#
# ### Pre-trained model (*Facebook/bart-large-mnli*):
#
# - Performs in a generalized way with low accuracy and precision using zero-shot-classification.
# - Showed bias towards *positive* and *negative* sentiments with high recall and low precision.
# - Performed poorly on *neutral* sentiment with lowest recall which gave high precision, resulting in lowest f1-score.
# - Resulted in bad total accuracy of `43%`.
# - Model is capable but needs retraining to learn the dataset.
#
# Classification report (Pre-trained model):
# ```
#               precision    recall  f1-score   support
#
#     negative       0.46      0.99      0.63       118
#      neutral       0.88      0.05      0.10       563
#     positive       0.40      0.94      0.56       287
#
#     accuracy                           0.43       968
#    macro avg       0.58      0.66      0.43       968
# weighted avg       0.68      0.43      0.30       968
# ```
#
#
# ### Fine-tuned model:
#
# - Learned the whole dataset really well and showed amazing performance.
# - Performed really well during training and reduced loss significantly.
# - Final *train loss*: `0.05` and *val loss*: `0.17`
# - Significant increase in overall accuracy across the sentiments.
# - NLI labels helped model capture complexities in text and sentiments.
# - Very good performance for all sentiments with high precision and recall values.
# - Resulted in high f1-score for all sentiments.
# - Achieved total accuracy of `98%`.
#
# Training data:
# ```
#  [7260/7260 43:59, Epoch 5/5]
# Step	Training Loss	Validation Loss
# 500	0.419700	0.507154
# 1000	0.440700	0.584067
# 1500	0.368300	0.371040
# 2000	0.270200	0.469932
# 2500	0.323200	0.333457
# 3000	0.273900	0.374012
# 3500	0.210700	0.307993
# 4000	0.158800	0.284700
# 4500	0.154500	0.304892
# 5000	0.127200	0.238853
# 5500	0.078700	0.208555
# 6000	0.056200	0.195520
# 6500	0.042000	0.178006
# 7000	0.053300	0.179048
# ```
#
# Classification report (Fine-tuned model):
# ```
#               precision    recall  f1-score   support
#
#     negative       0.95      0.97      0.96       118
#      neutral       0.99      0.99      0.99       563
#     positive       0.98      0.98      0.98       287
#
#     accuracy                           0.98       968
#    macro avg       0.97      0.98      0.97       968
# weighted avg       0.98      0.98      0.98       968
# ```
